# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
test = pd.read_csv("/home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1016/SVD_pair/5/f_Adult_2u_pos5_neg1_all_15recommendation.csv")

# %%
test.head(50)
# Out:
#     user_id  book_id  est_score  rank         genre_g1    genre_g2  \
# 0         1     9818   6.153554     1          Unknown         NaN
# 1         1     8747   5.883868     2       Nonfiction       Drama
# 2         1     9709   5.857887     3          Unknown         NaN
# 3         1     6759   5.855081     4          Unknown         NaN
# 4         1     5718   5.806920     5       Historical       Drama
# 5         1     7831   5.747281     6            Drama    Classics
# 6         1     5898   5.645753     7          Unknown         NaN
# 7         1     3575   5.553987     8          Fantasy  Children's
# 8         1     1376   5.544503     9          Fantasy   Adventure
# 9         1     6991   5.522650    10          Unknown         NaN
# 10        1     4869   5.519024    11       Children's   Adventure
# 11        1     4812   5.514390    12           Horror     Mystery
# 12        1     7537   5.506585    13       Nonfiction       Drama
# 13        1     4061   5.499641    14       Historical       Drama
# 14        1     6262   5.484875    15         Thriller     Mystery
# 15        2     9089   6.327304     1          Unknown         NaN
# 16        2     6759   6.148584     2          Unknown         NaN
# 17        2     5706   6.018067     3          Unknown         NaN
# 18        2     9922   5.977870     4         Thriller      Horror
# 19        2     8511   5.943603     5          Fantasy    Thriller
# 20        2     5353   5.874662     6       Children's  Nonfiction
# 21        2     9008   5.873316     7        Adventure    Thriller
# 22        2     5851   5.852865     8          Romance       Drama
# 23        2     8372   5.824587     9          Romance       Drama
# 24        2     9709   5.807511    10          Unknown         NaN
# 25        2     3842   5.803534    11           Horror     Mystery
# 26        2     6178   5.799715    12          Unknown         NaN
# 27        2     8567   5.787218    13          Mystery    Thriller
# 28        2     9191   5.751338    14         Classics     Mystery
# 29        2     8747   5.750125    15       Nonfiction       Drama
# 30        3     9394   4.886245     1          Romance       Drama
# 31        3     9534   4.225505     2          Unknown         NaN
# 32        3     7450   4.166099     3          Mystery       Drama
# 33        3     9829   4.095111     4            Adult       Drama
# 34        3     5543   4.026495     5          Romance       Adult
# 35        3     6253   3.998759     6          Unknown         NaN
# 36        3     6913   3.933362     7          Mystery       Drama
# 37        3     8854   3.916761     8       Historical     Romance
# 38        3     9105   3.841880     9          Romance       Drama
# 39        3     9624   3.832797    10       Nonfiction       Adult
# 40        3     7587   3.827670    11  Science Fiction   Adventure
# 41        3     5059   3.780764    12         Thriller     Mystery
# 42        3     9347   3.777363    13          Mystery    Thriller
# 43        3     6618   3.757144    14       Children's       Drama
# 44        3     6221   3.713979    15          Unknown         NaN
# 45        4     5268   5.832172     1       Nonfiction       Drama
# 46        4     7805   5.403789     2        Adventure     Mystery
# 47        4     9010   5.359430     3          Fantasy  Nonfiction
# 48        4     7831   5.357763     4            Drama    Classics
# 49        4     8358   5.354744     5           Horror     Mystery
#
#                     genres_all
# 0                      Unknown
# 1            Nonfiction, Drama
# 2                      Unknown
# 3                      Unknown
# 4            Historical, Drama
# 5              Drama, Classics
# 6                      Unknown
# 7          Fantasy, Children's
# 8           Fantasy, Adventure
# 9                      Unknown
# 10       Children's, Adventure
# 11             Horror, Mystery
# 12           Nonfiction, Drama
# 13           Historical, Drama
# 14           Thriller, Mystery
# 15                     Unknown
# 16                     Unknown
# 17                     Unknown
# 18            Thriller, Horror
# 19           Fantasy, Thriller
# 20      Children's, Nonfiction
# 21         Adventure, Thriller
# 22              Romance, Drama
# 23              Romance, Drama
# 24                     Unknown
# 25             Horror, Mystery
# 26                     Unknown
# 27           Mystery, Thriller
# 28           Classics, Mystery
# 29           Nonfiction, Drama
# 30              Romance, Drama
# 31                     Unknown
# 32              Mystery, Drama
# 33                Adult, Drama
# 34              Romance, Adult
# 35                     Unknown
# 36              Mystery, Drama
# 37         Historical, Romance
# 38              Romance, Drama
# 39           Nonfiction, Adult
# 40  Science Fiction, Adventure
# 41           Thriller, Mystery
# 42           Mystery, Thriller
# 43           Children's, Drama
# 44                     Unknown
# 45           Nonfiction, Drama
# 46          Adventure, Mystery
# 47         Fantasy, Nonfiction
# 48             Drama, Classics
# 49             Horror, Mystery

# %%
git add .
git commit -m " OR injection"
git push

# %%
#!/usr/bin/env python3
# make_pair_explanations_and_figs_1028.py
#
# Pair-injection analysis (SVD outputs) — produces FOUR figures per pair:
#   1) Single G1     (any book containing G1)
#   2) Single G2     (any book containing G2)
#   3) AND combo     (books containing BOTH G1 and G2)
#   4) OR  combo     (books containing G1 OR G2)
#
# Works with both AND (fpair_*) and OR (forpair_*) files discovered under 1028.
# ORIGINAL Top-K files are read from ORIG_DIR (your 1020 baseline).
#
# Per-pair outputs:
#   explanation.txt
#   per_book_ranking_pair.csv      (AND mask)
#   per_book_ranking_g1.csv
#   per_book_ranking_g2.csv
#   per_book_ranking_or.csv        (OR mask)
#   <slug>__single_g1_pos5.png
#   <slug>__single_g2_pos5.png
#   <slug>__and_pos5.png
#   <slug>__or_pos5.png
#
# Global rollups:
#   <OUT_BASE>/_all_pairs/summary_master.txt
#   <OUT_BASE>/_all_pairs/per_book_ranking_all.csv

from pathlib import Path
from typing import Optional, Dict, Tuple, List
import re
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

# ========= CONFIG =========
ROOT        = Path("/home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028")
ORIG_DIR    = Path("/home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1020/SVD_pair")
SEARCH_ROOT = ROOT                 # where we search for pair files (AND + OR)
OUT_BASE    = ROOT / "result" / "5_pair"

K_LIST = [15, 25, 35]
N_LIST = [2, 6, 200]

# Broad patterns for fast walking; exact matching is done via regex later.
PAIR_INJECTION_PATTERNS = [
    "fpair_*__*_*u_pos5_neg*_*recommendation.csv",
    "forpair_*__*_*u_pos5_neg*_*recommendation.csv",
    "fpair_*__*_*u_pos5_neg*_*recommendation.csv.gz",
    "forpair_*__*_*u_pos5_neg*_*recommendation.csv.gz",
]

def _clean_space_lower(s: str) -> str:
    s = re.sub(r"\s+", " ", str(s).strip())
    return s.lower()

GENRE_NORM = {
    "adventure": "adventure", "classics": "classics", "drama": "drama",
    "fantasy": "fantasy", "historical": "historical", "horror": "horror",
    "mystery": "mystery", "nonfiction": "nonfiction", "romance": "romance",
    "science fiction": "science fiction", "thriller": "thriller",
    "children's": "children's", "adult": "adult",
    "children_s": "children's", "childrens": "children's", "children’s": "children's", "children": "children's",
    "sci-fi": "science fiction", "scifi": "science fiction", "science_finction": "science fiction",
    "adventre": "adventure", "advenbture": "adventure", "science_fiction": "science fiction",
}
DISPLAY_MAP = {
    "adventure": "Adventure", "classics": "Classics", "drama": "Drama", "fantasy": "Fantasy",
    "historical": "Historical", "horror": "Horror", "mystery": "Mystery", "nonfiction": "Nonfiction",
    "romance": "Romance", "science fiction": "Science Fiction", "thriller": "Thriller",
    "children's": "Children's", "adult": "Adult",
}

def norm_token(s: str) -> str:
    low = _clean_space_lower(s).replace("_", " ")
    return GENRE_NORM.get(low, low)

def display_canonical(s: str) -> str:
    low = norm_token(s)
    return DISPLAY_MAP.get(low, s)

def slugify_token(x: str) -> str:
    x = re.sub(r"[^A-Za-z0-9]+", "_", str(x)).strip("_").lower()
    return re.sub(r"_+", "_", x)

# ========= IO helpers (robust CSV loader) ====================================
def _pd_read_csv_robust(handle, *, try_c_first=True):
    if try_c_first:
        try:
            return pd.read_csv(handle, engine="c", on_bad_lines="skip")
        except Exception:
            pass
    return pd.read_csv(handle, engine="python")

def load_rec_csv(fp: Path) -> pd.DataFrame:
    import io, gzip, bz2, lzma, zipfile
    with open(fp, "rb") as f:
        head = f.read(8)

    compression = None
    if head.startswith(b"\x1f\x8b"):
        compression = "gzip"
    elif head.startswith(b"BZh"):
        compression = "bz2"
    elif head.startswith(b"\xfd7zXZ\x00"):
        compression = "xz"
    elif head.startswith(b"PK"):
        compression = "zip"

    def _read_with(enc: str):
        if compression == "gzip":
            with gzip.open(fp, "rt", encoding=enc, errors="strict") as f:
                return _pd_read_csv_robust(f)
        elif compression == "bz2":
            with bz2.open(fp, "rt", encoding=enc, errors="strict") as f:
                return _pd_read_csv_robust(f)
        elif compression == "xz":
            with lzma.open(fp, "rt", encoding=enc, errors="strict") as f:
                return _pd_read_csv_robust(f)
        elif compression == "zip":
            with zipfile.ZipFile(fp) as zf:
                name = next((n for n in zf.namelist() if n.lower().endswith(".csv")), None)
                if name is None:
                    raise ValueError(f"No CSV inside zip: {fp}")
                with zf.open(name) as zfobj:
                    text = io.TextIOWrapper(zfobj, encoding=enc, errors="strict")
                    return _pd_read_csv_robust(text)
        else:
            try:
                return pd.read_csv(fp, engine="c", on_bad_lines="skip", encoding=enc)
            except Exception:
                return pd.read_csv(fp, engine="python", encoding=enc)

    try:
        df = _read_with("utf-8")
    except UnicodeDecodeError:
        df = _read_with("latin-1")

    if "genres_all" not in df.columns:
        df["genres_all"] = ""
    for c in ["user_id", "book_id", "rank", "est_score", "original_title"]:
        if c not in df.columns:
            df[c] = pd.NA
    return df

def _tokenize_genres(cell) -> List[str]:
    if pd.isna(cell):
        return []
    return [norm_token(t.strip()) for t in str(cell).split(",") if t.strip()]

def has_genre(cell, target_canon_lc: str) -> bool:
    return target_canon_lc in _tokenize_genres(cell)

def has_both(cell, g1_lc: str, g2_lc: str) -> bool:
    toks = _tokenize_genres(cell)
    return (g1_lc in toks) and (g2_lc in toks)

def metrics_for_mask(df: pd.DataFrame, mask: pd.Series) -> Tuple[int, float, int, int, int]:
    unique_books_in_file = df["book_id"].nunique() if "book_id" in df.columns else 0
    if "user_id" in df.columns:
        per_user = df.assign(_m=mask).groupby("user_id")["_m"].sum()
        avg_per_user = float(per_user.mean()) if not per_user.empty else 0.0
        users_with_target = int((per_user > 0).sum())
    else:
        avg_per_user = 0.0
        users_with_target = 0
    unique_tg_books = df.loc[mask, "book_id"].nunique() if "book_id" in df.columns else 0
    freq = int(mask.sum())
    return unique_books_in_file, avg_per_user, unique_tg_books, freq, users_with_target

def per_book_ranking(df_target_rows: pd.DataFrame) -> pd.DataFrame:
    if df_target_rows.empty:
        return pd.DataFrame(columns=[
            "book_id","rank","freq","users_n","avg_rank","avg_est_score","rank1_count","original_title","genres_all"
        ])
    g = df_target_rows.groupby("book_id", as_index=False)
    out = g.agg(
        freq=("book_id", "size"),
        users_n=("user_id", "nunique"),
        avg_rank=("rank", "mean"),
        avg_est_score=("est_score", "mean"),
        rank1_count=("rank", lambda s: int((s == 1).sum())),
    )
    for c in ["original_title", "genres_all"]:
        smpl = df_target_rows.groupby("book_id")[c].apply(
            lambda s: s.dropna().iloc[0] if s.notna().any() else pd.NA
        ).reset_index(name=c)
        out = out.merge(smpl, on="book_id", how="left")
    out = out.sort_values(["freq","rank1_count","avg_rank"], ascending=[False, False, True]).reset_index(drop=True)
    out.insert(1, "rank", out.index + 1)
    return out

PAIR_FILE_RE = re.compile(
    r"^(?:fpair|forpair)_(.+?)__([^.]+?)_(\d+)u_pos\d+_neg[^_]+.*_(\d+)recommendation\.csv(?:\.gz)?$",
    re.IGNORECASE
)

def extract_pair_from_filename(p: Path) -> Optional[Tuple[str, str, int, int]]:
    m = PAIR_FILE_RE.match(p.name)
    if not m:
        return None
    g1_raw, g2_raw = m.group(1), m.group(2)
    g1 = norm_token(g1_raw.replace("_", " "))
    g2 = norm_token(g2_raw.replace("_", " "))
    N = int(m.group(3))
    K = int(m.group(4))
    return g1, g2, N, K

def find_pair_file(g1_disp: str, g2_disp: str, n: int, k: int) -> Optional[Path]:
    """Find a matching file for the pair {g1,g2}, cohort N, and Top-K (works for fpair_* or forpair_*)."""
    g1 = norm_token(g1_disp)
    g2 = norm_token(g2_disp)
    for patt in PAIR_INJECTION_PATTERNS:
        for p in SEARCH_ROOT.rglob(patt):
            info = extract_pair_from_filename(p)
            if not info:
                continue
            g1f, g2f, Nf, Kf = info
            if {g1f, g2f} == {g1, g2} and Nf == n and Kf == k:
                return p
    return None

def pair_key_disp(g1: str, g2: str) -> Tuple[str, str, str]:
    g1d = display_canonical(g1)
    g2d = display_canonical(g2)
    key = re.sub(r"[^\w\-]+", "_", f"{g1d}__{g2d}")
    disp = f"{g1d} + {g2d}"
    slug = slugify_token(f"{g1d}__{g2d}")
    return key, disp, slug

# ========= Pretty progress printing =========
def print_pair_progress(pair_disp: str, K: int, filename: str,
                        unique_books_in_file: int, avg_per_user: float, unique_tg_books: int, tag: str):
    # tag ∈ {"AND","OR","G1","G2","Original-AND","Original-OR","Original-G1","Original-G2"}
    print(f"[{pair_disp}] [{K}] ({tag}) {filename} -> {unique_books_in_file} books -> "
          f"{pair_disp} {tag}: avg/user={avg_per_user:.2f}, unique={unique_tg_books}")

# ========= Plotting (no numbers on bars) =========
def plot_subset(pair_disp: str,
                data_by_k: Dict[int, Dict[str, float]],
                ylabel: str,
                title_suffix: str,
                out_png: Path):
    ks = sorted(data_by_k.keys())
    if not ks:
        return
    groups = ["Original"] + [str(x) for x in N_LIST]
    present_groups = [g for g in groups if any(g in data_by_k.get(k, {}) for k in ks)]
    width = 0.8 / max(1, len(present_groups))
    x = list(range(len(ks)))
    plt.figure(figsize=(8.6, 4.4), dpi=160)
    for j, g in enumerate(present_groups):
        offs = [i + (j - (len(present_groups)-1)/2)*width for i in x]
        vals = [float(data_by_k.get(k, {}).get(g, 0.0)) for k in ks]
        plt.bar(offs, vals, width=width, label=("n="+g if g!="Original" else "Original"))
    plt.xticks(x, [f"Top-{k}" for k in ks])
    plt.ylabel(ylabel)
    plt.title(f"{pair_disp} — POS=5 ({title_suffix})")
    plt.legend(ncol=min(4, len(present_groups)), fontsize=9)
    plt.tight_layout()
    out_png.parent.mkdir(parents=True, exist_ok=True)
    plt.savefig(out_png)
    plt.close()

# ========= Per-pair processing =========
def process_one_pair(g1: str, g2: str) -> Dict:
    PAIR_KEY, PAIR_DISP, PAIR_SLUG = pair_key_disp(g1, g2)
    OUT_DIR = OUT_BASE / f"{PAIR_KEY}_pair_explanation"
    OUT_DIR.mkdir(parents=True, exist_ok=True)

    # Separate dashboards for each subset
    fig_pairboth: Dict[int, Dict[str, float]] = {k: {} for k in K_LIST}  # AND
    fig_g1:       Dict[int, Dict[str, float]] = {k: {} for k in K_LIST}  # single G1
    fig_g2:       Dict[int, Dict[str, float]] = {k: {} for k in K_LIST}  # single G2
    fig_or:       Dict[int, Dict[str, float]] = {k: {} for k in K_LIST}  # OR (union)

    g1_lc = norm_token(g1)
    g2_lc = norm_token(g2)

    def make_masks(df: pd.DataFrame):
        g1_m   = df["genres_all"].apply(lambda s: has_genre(s, g1_lc))
        g2_m   = df["genres_all"].apply(lambda s: has_genre(s, g2_lc))
        both_m = df["genres_all"].apply(lambda s: has_both(s, g1_lc, g2_lc))
        or_m   = g1_m | g2_m
        return g1_m, g2_m, both_m, or_m

    # Per-book rankings we’ll persist
    per_book_rows_both: List[Dict] = []
    per_book_rows_g1:   List[Dict] = []
    per_book_rows_g2:   List[Dict] = []
    per_book_rows_or:   List[Dict] = []

    original_uniques = {
        "AND": {}, "G1": {}, "G2": {}, "OR": {}
    }
    injection_uniques = {
        "AND": {}, "G1": {}, "G2": {}, "OR": {}
    }  # keyed by (N,K) for injections

    # ---------- ORIGINAL ----------
    for K in K_LIST:
        fp = ORIG_DIR / f"ORIGINAL_{K}recommendation.csv"
        if not fp.exists():
            print(f"[warn][{PAIR_DISP}] Missing ORIGINAL for K={K}: {fp}")
            continue
        df = load_rec_csv(fp)
        g1_m, g2_m, both_m, or_m = make_masks(df)

        # G1
        uniqB, avgU, uniqT, _, _ = metrics_for_mask(df, g1_m)
        original_uniques["G1"][K] = uniqT
        fig_g1[K]["Original"] = avgU
        print_pair_progress(PAIR_DISP, K, fp.name, uniqB, avgU, uniqT, "Original-G1")
        ranked = per_book_ranking(df.loc[g1_m].copy())
        for _, r in ranked.iterrows():
            per_book_rows_g1.append({
                "pair": PAIR_DISP, "subset": "g1", "dataset": f"original{K}",
                "book_id": int(r["book_id"]), "rank": int(r["rank"]), "freq": int(r["freq"]),
                "users_n": int(r["users_n"]),
                "avg_rank": float(r["avg_rank"]) if pd.notna(r["avg_rank"]) else None,
                "avg_est_score": float(r["avg_est_score"]) if pd.notna(r["avg_est_score"]) else None,
                "rank1_count": int(r["rank1_count"]),
                "original_title": r.get("original_title", pd.NA),
                "genres_all": r.get("genres_all", pd.NA),
            })

        # G2
        uniqB, avgU, uniqT, _, _ = metrics_for_mask(df, g2_m)
        original_uniques["G2"][K] = uniqT
        fig_g2[K]["Original"] = avgU
        print_pair_progress(PAIR_DISP, K, fp.name, uniqB, avgU, uniqT, "Original-G2")
        ranked = per_book_ranking(df.loc[g2_m].copy())
        for _, r in ranked.iterrows():
            per_book_rows_g2.append({
                "pair": PAIR_DISP, "subset": "g2", "dataset": f"original{K}",
                "book_id": int(r["book_id"]), "rank": int(r["rank"]), "freq": int(r["freq"]),
                "users_n": int(r["users_n"]),
                "avg_rank": float(r["avg_rank"]) if pd.notna(r["avg_rank"]) else None,
                "avg_est_score": float(r["avg_est_score"]) if pd.notna(r["avg_est_score"]) else None,
                "rank1_count": int(r["rank1_count"]),
                "original_title": r.get("original_title", pd.NA),
                "genres_all": r.get("genres_all", pd.NA),
            })

        # AND (pair_both)
        uniqB, avgU, uniqT, _, _ = metrics_for_mask(df, both_m)
        original_uniques["AND"][K] = uniqT
        fig_pairboth[K]["Original"] = avgU
        print_pair_progress(PAIR_DISP, K, fp.name, uniqB, avgU, uniqT, "Original-AND")
        ranked = per_book_ranking(df.loc[both_m].copy())
        for _, r in ranked.iterrows():
            per_book_rows_both.append({
                "pair": PAIR_DISP, "subset": "pair_both", "dataset": f"original{K}",
                "book_id": int(r["book_id"]), "rank": int(r["rank"]), "freq": int(r["freq"]),
                "users_n": int(r["users_n"]),
                "avg_rank": float(r["avg_rank"]) if pd.notna(r["avg_rank"]) else None,
                "avg_est_score": float(r["avg_est_score"]) if pd.notna(r["avg_est_score"]) else None,
                "rank1_count": int(r["rank1_count"]),
                "original_title": r.get("original_title", pd.NA),
                "genres_all": r.get("genres_all", pd.NA),
            })

        # OR (union)
        uniqB, avgU, uniqT, _, _ = metrics_for_mask(df, or_m)
        original_uniques["OR"][K] = uniqT
        fig_or[K]["Original"] = avgU
        print_pair_progress(PAIR_DISP, K, fp.name, uniqB, avgU, uniqT, "Original-OR")
        ranked = per_book_ranking(df.loc[or_m].copy())
        for _, r in ranked.iterrows():
            per_book_rows_or.append({
                "pair": PAIR_DISP, "subset": "or", "dataset": f"original{K}",
                "book_id": int(r["book_id"]), "rank": int(r["rank"]), "freq": int(r["freq"]),
                "users_n": int(r["users_n"]),
                "avg_rank": float(r["avg_rank"]) if pd.notna(r["avg_rank"]) else None,
                "avg_est_score": float(r["avg_est_score"]) if pd.notna(r["avg_est_score"]) else None,
                "rank1_count": int(r["rank1_count"]),
                "original_title": r.get("original_title", pd.NA),
                "genres_all": r.get("genres_all", pd.NA),
            })

    # ---------- INJECTIONS (AND + OR; whichever files exist) ----------
    for K in K_LIST:
        for N in N_LIST:
            fp = find_pair_file(g1, g2, N, K)
            if not fp:
                print(f"[warn][{PAIR_DISP}] Missing pair file for N={N}, K={K}")
                continue
            df = load_rec_csv(fp)
            g1_m, g2_m, both_m, or_m = make_masks(df)

            # G1
            uniqB, avgU, uniqT, _, _ = metrics_for_mask(df, g1_m)
            injection_uniques["G1"][(N, K)] = uniqT
            fig_g1[K][str(N)] = avgU
            print_pair_progress(PAIR_DISP, K, fp.name, uniqB, avgU, uniqT, "G1")
            ranked = per_book_ranking(df.loc[g1_m].copy())
            for _, r in ranked.iterrows():
                per_book_rows_g1.append({
                    "pair": PAIR_DISP, "subset": "g1", "dataset": f"{N}u_{K}",
                    "book_id": int(r["book_id"]), "rank": int(r["rank"]), "freq": int(r["freq"]),
                    "users_n": int(r["users_n"]),
                    "avg_rank": float(r["avg_rank"]) if pd.notna(r["avg_rank"]) else None,
                    "avg_est_score": float(r["avg_est_score"]) if pd.notna(r["avg_est_score"]) else None,
                    "rank1_count": int(r["rank1_count"]),
                    "original_title": r.get("original_title", pd.NA),
                    "genres_all": r.get("genres_all", pd.NA),
                })

            # G2
            uniqB, avgU, uniqT, _, _ = metrics_for_mask(df, g2_m)
            injection_uniques["G2"][(N, K)] = uniqT
            fig_g2[K][str(N)] = avgU
            print_pair_progress(PAIR_DISP, K, fp.name, uniqB, avgU, uniqT, "G2")
            ranked = per_book_ranking(df.loc[g2_m].copy())
            for _, r in ranked.iterrows():
                per_book_rows_g2.append({
                    "pair": PAIR_DISP, "subset": "g2", "dataset": f"{N}u_{K}",
                    "book_id": int(r["book_id"]), "rank": int(r["rank"]), "freq": int(r["freq"]),
                    "users_n": int(r["users_n"]),
                    "avg_rank": float(r["avg_rank"]) if pd.notna(r["avg_rank"]) else None,
                    "avg_est_score": float(r["avg_est_score"]) if pd.notna(r["avg_est_score"]) else None,
                    "rank1_count": int(r["rank1_count"]),
                    "original_title": r.get("original_title", pd.NA),
                    "genres_all": r.get("genres_all", pd.NA),
                })

            # AND
            uniqB, avgU, uniqT, _, _ = metrics_for_mask(df, both_m)
            injection_uniques["AND"][(N, K)] = uniqT
            fig_pairboth[K][str(N)] = avgU
            print_pair_progress(PAIR_DISP, K, fp.name, uniqB, avgU, uniqT, "AND")
            ranked = per_book_ranking(df.loc[both_m].copy())
            for _, r in ranked.iterrows():
                per_book_rows_both.append({
                    "pair": PAIR_DISP, "subset": "pair_both", "dataset": f"{N}u_{K}",
                    "book_id": int(r["book_id"]), "rank": int(r["rank"]), "freq": int(r["freq"]),
                    "users_n": int(r["users_n"]),
                    "avg_rank": float(r["avg_rank"]) if pd.notna(r["avg_rank"]) else None,
                    "avg_est_score": float(r["avg_est_score"]) if pd.notna(r["avg_est_score"]) else None,
                    "rank1_count": int(r["rank1_count"]),
                    "original_title": r.get("original_title", pd.NA),
                    "genres_all": r.get("genres_all", pd.NA),
                })

            # OR
            uniqB, avgU, uniqT, _, _ = metrics_for_mask(df, or_m)
            injection_uniques["OR"][(N, K)] = uniqT
            fig_or[K][str(N)] = avgU
            print_pair_progress(PAIR_DISP, K, fp.name, uniqB, avgU, uniqT, "OR")
            ranked = per_book_ranking(df.loc[or_m].copy())
            for _, r in ranked.iterrows():
                per_book_rows_or.append({
                    "pair": PAIR_DISP, "subset": "or", "dataset": f"{N}u_{K}",
                    "book_id": int(r["book_id"]), "rank": int(r["rank"]), "freq": int(r["freq"]),
                    "users_n": int(r["users_n"]),
                    "avg_rank": float(r["avg_rank"]) if pd.notna(r["avg_rank"]) else None,
                    "avg_est_score": float(r["avg_est_score"]) if pd.notna(r["avg_est_score"]) else None,
                    "rank1_count": int(r["rank1_count"]),
                    "original_title": r.get("original_title", pd.NA),
                    "genres_all": r.get("genres_all", pd.NA),
                })

    # ---------- Write text summary ----------
    text_path = OUT_DIR / "explanation.txt"
    with open(text_path, "w", encoding="utf-8") as f:
        f.write(f"{PAIR_DISP}:\n")
        for subset_name, human in [("AND","pair_both (AND)"),
                                   ("OR","pair_or (OR)"),
                                   ("G1","single G1"),
                                   ("G2","single G2")]:
            f.write(f"\n{human}:\n")
            for K in K_LIST:
                v = original_uniques[subset_name].get(K)
                if v is not None:
                    f.write(f"  original {K}: unique_books: {v}\n")
            for K in K_LIST:
                for N in N_LIST:
                    val = injection_uniques[subset_name].get((N, K))
                    if val is not None:
                        f.write(f"  {N}u, {K}, unique_books: {val}\n")

    # ---------- Write CSVs ----------
    pd.DataFrame(per_book_rows_both).to_csv(OUT_DIR / "per_book_ranking_pair.csv", index=False)  # AND
    pd.DataFrame(per_book_rows_g1).to_csv(OUT_DIR / "per_book_ranking_g1.csv", index=False)
    pd.DataFrame(per_book_rows_g2).to_csv(OUT_DIR / "per_book_ranking_g2.csv", index=False)
    pd.DataFrame(per_book_rows_or).to_csv(OUT_DIR / "per_book_ranking_or.csv", index=False)      # OR

    # ---------- Four Figures ----------
    fig_and = OUT_DIR / f"{PAIR_SLUG}__and_pos5.png"
    fig_or_ = OUT_DIR / f"{PAIR_SLUG}__or_pos5.png"
    fig_g1p = OUT_DIR / f"{PAIR_SLUG}__single_g1_pos5.png"
    fig_g2p = OUT_DIR / f"{PAIR_SLUG}__single_g2_pos5.png"

    plot_subset(PAIR_DISP, fig_g1, "Avg # of G1 books in Top-K per user", "Single G1", fig_g1p)
    plot_subset(PAIR_DISP, fig_g2, "Avg # of G2 books in Top-K per user", "Single G2", fig_g2p)
    plot_subset(PAIR_DISP, fig_pairboth, "Avg # of AND (both) books in Top-K per user", "AND", fig_and)
    plot_subset(PAIR_DISP, fig_or, "Avg # of OR (either) books in Top-K per user", "OR", fig_or_)

    print(f"[OK][{PAIR_DISP}] Saved text:   {text_path}")
    print(f"[OK][{PAIR_DISP}] Saved tables: "
          f"{OUT_DIR/'per_book_ranking_pair.csv'}, "
          f"{OUT_DIR/'per_book_ranking_g1.csv'}, "
          f"{OUT_DIR/'per_book_ranking_g2.csv'}, "
          f"{OUT_DIR/'per_book_ranking_or.csv'}")
    print(f"[OK][{PAIR_DISP}] Saved figures: {fig_g1p}, {fig_g2p}, {fig_and}, {fig_or_}")

    return {
        "pair": PAIR_DISP,
        "out_dir": OUT_DIR,
        "per_book_rows_both": per_book_rows_both,
        "per_book_rows_g1": per_book_rows_g1,
        "per_book_rows_g2": per_book_rows_g2,
        "per_book_rows_or": per_book_rows_or,
    }

# ========= MAIN =========
EXPLICIT_PAIRS: List[Tuple[str, str]] = []  # e.g., [("Horror", "Nonfiction")]

def discover_pairs_from_files() -> List[Tuple[str, str]]:
    """Discover all pairs by scanning files (no specific-genre filtering)."""
    seen = set()
    seeds = [(2, 15), (6, 25), (50, 35), (1000, 15), (1000, 35)]
    for n, k in seeds:
        for patt in PAIR_INJECTION_PATTERNS:
            for p in SEARCH_ROOT.rglob(patt):
                info = extract_pair_from_filename(p)
                if not info:
                    continue
                g1, g2, _, _ = info
                seen.add(tuple(sorted((g1, g2))))
    return sorted([(a, b) for (a, b) in seen])

def main():
    OUT_ALL = OUT_BASE / "_all_pairs"
    OUT_ALL.mkdir(parents=True, exist_ok=True)

    if EXPLICIT_PAIRS:
        pairs = EXPLICIT_PAIRS
    else:
        pairs = discover_pairs_from_files()
        if not pairs:
            print("[warn] No pairs discovered. Set EXPLICIT_PAIRS=[('Horror','Nonfiction')] to run explicitly.")
            return
    print(f"[info] Pairs to analyze: {len(pairs)} → {pairs[:5]}{' ...' if len(pairs)>5 else ''}")

    all_rows: List[Dict] = []
    master_lines: List[str] = []

    for g1, g2 in pairs:
        res = process_one_pair(g1, g2)
        master_lines.append(f"{res['pair']}:")
        master_lines.append("")
        all_rows.extend(res["per_book_rows_both"])
        all_rows.extend(res["per_book_rows_g1"])
        all_rows.extend(res["per_book_rows_g2"])
        all_rows.extend(res["per_book_rows_or"])

    master_txt = OUT_ALL / "summary_master.txt"
    with open(master_txt, "w", encoding="utf-8") as f:
        f.write("\n".join(master_lines))
    print(f"[OK] Wrote master summary: {master_txt}")

    if all_rows:
        pd.DataFrame(all_rows).to_csv(OUT_ALL / "per_book_ranking_all.csv", index=False)
        print(f"[OK] Wrote global per-book ranking CSV: {OUT_ALL / 'per_book_ranking_all.csv'}")
    else:
        print("[warn] No per-book rows produced. Check inputs / paths / patterns.")

if __name__ == "__main__":
    main()
# Out:
# [info] Pairs to analyze: 48 → [('adult', 'adventure'), ('adult', 'children s'), ('adult', 'classics'), ('adult', 'drama'), ('adult', 'fantasy')] ...
# [Adult + Adventure] [15] (Original-G1) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Adventure Original-G1: avg/user=0.60, unique=86
# [Adult + Adventure] [15] (Original-G2) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Adventure Original-G2: avg/user=2.87, unique=398
# [Adult + Adventure] [15] (Original-AND) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Adventure Original-AND: avg/user=0.00, unique=0
# [Adult + Adventure] [15] (Original-OR) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Adventure Original-OR: avg/user=3.47, unique=484
# [Adult + Adventure] [25] (Original-G1) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Adventure Original-G1: avg/user=0.94, unique=110
# [Adult + Adventure] [25] (Original-G2) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Adventure Original-G2: avg/user=4.90, unique=549
# [Adult + Adventure] [25] (Original-AND) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Adventure Original-AND: avg/user=0.00, unique=0
# [Adult + Adventure] [25] (Original-OR) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Adventure Original-OR: avg/user=5.84, unique=659
# [Adult + Adventure] [35] (Original-G1) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Adventure Original-G1: avg/user=1.25, unique=129
# [Adult + Adventure] [35] (Original-G2) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Adventure Original-G2: avg/user=6.99, unique=663
# [Adult + Adventure] [35] (Original-AND) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Adventure Original-AND: avg/user=0.00, unique=0
# [Adult + Adventure] [35] (Original-OR) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Adventure Original-OR: avg/user=8.23, unique=792
# [Adult + Adventure] [15] (G1) forpair_Adult__Adventure_2u_pos5_neg1_OR_15recommendation.csv -> 2042 books -> Adult + Adventure G1: avg/user=0.51, unique=93
# [Adult + Adventure] [15] (G2) forpair_Adult__Adventure_2u_pos5_neg1_OR_15recommendation.csv -> 2042 books -> Adult + Adventure G2: avg/user=2.94, unique=404
# [Adult + Adventure] [15] (AND) forpair_Adult__Adventure_2u_pos5_neg1_OR_15recommendation.csv -> 2042 books -> Adult + Adventure AND: avg/user=0.00, unique=0
# [Adult + Adventure] [15] (OR) forpair_Adult__Adventure_2u_pos5_neg1_OR_15recommendation.csv -> 2042 books -> Adult + Adventure OR: avg/user=3.45, unique=497
# [Adult + Adventure] [15] (G1) forpair_Adult__Adventure_6u_pos5_neg1_OR_15recommendation.csv -> 1954 books -> Adult + Adventure G1: avg/user=0.68, unique=96
# [Adult + Adventure] [15] (G2) forpair_Adult__Adventure_6u_pos5_neg1_OR_15recommendation.csv -> 1954 books -> Adult + Adventure G2: avg/user=3.68, unique=425
# [Adult + Adventure] [15] (AND) forpair_Adult__Adventure_6u_pos5_neg1_OR_15recommendation.csv -> 1954 books -> Adult + Adventure AND: avg/user=0.00, unique=0
# [Adult + Adventure] [15] (OR) forpair_Adult__Adventure_6u_pos5_neg1_OR_15recommendation.csv -> 1954 books -> Adult + Adventure OR: avg/user=4.35, unique=521
# [Adult + Adventure] [15] (G1) forpair_Adult__Adventure_200u_pos5_neg1_OR_15recommendation.csv -> 2067 books -> Adult + Adventure G1: avg/user=0.97, unique=99
# [Adult + Adventure] [15] (G2) forpair_Adult__Adventure_200u_pos5_neg1_OR_15recommendation.csv -> 2067 books -> Adult + Adventure G2: avg/user=4.14, unique=544
# [Adult + Adventure] [15] (AND) forpair_Adult__Adventure_200u_pos5_neg1_OR_15recommendation.csv -> 2067 books -> Adult + Adventure AND: avg/user=0.00, unique=0
# [Adult + Adventure] [15] (OR) forpair_Adult__Adventure_200u_pos5_neg1_OR_15recommendation.csv -> 2067 books -> Adult + Adventure OR: avg/user=5.12, unique=643
# [Adult + Adventure] [25] (G1) forpair_Adult__Adventure_2u_pos5_neg1_OR_25recommendation.csv -> 2742 books -> Adult + Adventure G1: avg/user=0.82, unique=115
# [Adult + Adventure] [25] (G2) forpair_Adult__Adventure_2u_pos5_neg1_OR_25recommendation.csv -> 2742 books -> Adult + Adventure G2: avg/user=5.21, unique=568
# [Adult + Adventure] [25] (AND) forpair_Adult__Adventure_2u_pos5_neg1_OR_25recommendation.csv -> 2742 books -> Adult + Adventure AND: avg/user=0.00, unique=0
# [Adult + Adventure] [25] (OR) forpair_Adult__Adventure_2u_pos5_neg1_OR_25recommendation.csv -> 2742 books -> Adult + Adventure OR: avg/user=6.03, unique=683
# [Adult + Adventure] [25] (G1) forpair_Adult__Adventure_6u_pos5_neg1_OR_25recommendation.csv -> 2664 books -> Adult + Adventure G1: avg/user=1.08, unique=115
# [Adult + Adventure] [25] (G2) forpair_Adult__Adventure_6u_pos5_neg1_OR_25recommendation.csv -> 2664 books -> Adult + Adventure G2: avg/user=6.40, unique=566
# [Adult + Adventure] [25] (AND) forpair_Adult__Adventure_6u_pos5_neg1_OR_25recommendation.csv -> 2664 books -> Adult + Adventure AND: avg/user=0.00, unique=0
# [Adult + Adventure] [25] (OR) forpair_Adult__Adventure_6u_pos5_neg1_OR_25recommendation.csv -> 2664 books -> Adult + Adventure OR: avg/user=7.47, unique=681
# [Adult + Adventure] [25] (G1) forpair_Adult__Adventure_200u_pos5_neg1_OR_25recommendation.csv -> 2797 books -> Adult + Adventure G1: avg/user=1.50, unique=135
# [Adult + Adventure] [25] (G2) forpair_Adult__Adventure_200u_pos5_neg1_OR_25recommendation.csv -> 2797 books -> Adult + Adventure G2: avg/user=7.33, unique=705
# [Adult + Adventure] [25] (AND) forpair_Adult__Adventure_200u_pos5_neg1_OR_25recommendation.csv -> 2797 books -> Adult + Adventure AND: avg/user=0.00, unique=0
# [Adult + Adventure] [25] (OR) forpair_Adult__Adventure_200u_pos5_neg1_OR_25recommendation.csv -> 2797 books -> Adult + Adventure OR: avg/user=8.83, unique=840
# [Adult + Adventure] [35] (G1) forpair_Adult__Adventure_2u_pos5_neg1_OR_35recommendation.csv -> 3307 books -> Adult + Adventure G1: avg/user=1.11, unique=133
# [Adult + Adventure] [35] (G2) forpair_Adult__Adventure_2u_pos5_neg1_OR_35recommendation.csv -> 3307 books -> Adult + Adventure G2: avg/user=7.53, unique=680
# [Adult + Adventure] [35] (AND) forpair_Adult__Adventure_2u_pos5_neg1_OR_35recommendation.csv -> 3307 books -> Adult + Adventure AND: avg/user=0.00, unique=0
# [Adult + Adventure] [35] (OR) forpair_Adult__Adventure_2u_pos5_neg1_OR_35recommendation.csv -> 3307 books -> Adult + Adventure OR: avg/user=8.64, unique=813
# [Adult + Adventure] [35] (G1) forpair_Adult__Adventure_6u_pos5_neg1_OR_35recommendation.csv -> 3165 books -> Adult + Adventure G1: avg/user=1.48, unique=137
# [Adult + Adventure] [35] (G2) forpair_Adult__Adventure_6u_pos5_neg1_OR_35recommendation.csv -> 3165 books -> Adult + Adventure G2: avg/user=9.10, unique=671
# [Adult + Adventure] [35] (AND) forpair_Adult__Adventure_6u_pos5_neg1_OR_35recommendation.csv -> 3165 books -> Adult + Adventure AND: avg/user=0.00, unique=0
# [Adult + Adventure] [35] (OR) forpair_Adult__Adventure_6u_pos5_neg1_OR_35recommendation.csv -> 3165 books -> Adult + Adventure OR: avg/user=10.57, unique=808
# [Adult + Adventure] [35] (G1) forpair_Adult__Adventure_200u_pos5_neg1_OR_35recommendation.csv -> 3410 books -> Adult + Adventure G1: avg/user=1.97, unique=163
# [Adult + Adventure] [35] (G2) forpair_Adult__Adventure_200u_pos5_neg1_OR_35recommendation.csv -> 3410 books -> Adult + Adventure G2: avg/user=10.54, unique=855
# [Adult + Adventure] [35] (AND) forpair_Adult__Adventure_200u_pos5_neg1_OR_35recommendation.csv -> 3410 books -> Adult + Adventure AND: avg/user=0.00, unique=0
# [Adult + Adventure] [35] (OR) forpair_Adult__Adventure_200u_pos5_neg1_OR_35recommendation.csv -> 3410 books -> Adult + Adventure OR: avg/user=12.51, unique=1018
# [OK][Adult + Adventure] Saved text:   /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Adventure_pair_explanation/explanation.txt
# [OK][Adult + Adventure] Saved tables: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Adventure_pair_explanation/per_book_ranking_pair.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Adventure_pair_explanation/per_book_ranking_g1.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Adventure_pair_explanation/per_book_ranking_g2.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Adventure_pair_explanation/per_book_ranking_or.csv
# [OK][Adult + Adventure] Saved figures: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Adventure_pair_explanation/adult_adventure__single_g1_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Adventure_pair_explanation/adult_adventure__single_g2_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Adventure_pair_explanation/adult_adventure__and_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Adventure_pair_explanation/adult_adventure__or_pos5.png
# [Adult + children s] [15] (Original-G1) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + children s Original-G1: avg/user=0.60, unique=86
# [Adult + children s] [15] (Original-G2) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + children s Original-G2: avg/user=0.00, unique=0
# [Adult + children s] [15] (Original-AND) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + children s Original-AND: avg/user=0.00, unique=0
# [Adult + children s] [15] (Original-OR) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + children s Original-OR: avg/user=0.60, unique=86
# [Adult + children s] [25] (Original-G1) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + children s Original-G1: avg/user=0.94, unique=110
# [Adult + children s] [25] (Original-G2) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + children s Original-G2: avg/user=0.00, unique=0
# [Adult + children s] [25] (Original-AND) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + children s Original-AND: avg/user=0.00, unique=0
# [Adult + children s] [25] (Original-OR) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + children s Original-OR: avg/user=0.94, unique=110
# [Adult + children s] [35] (Original-G1) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + children s Original-G1: avg/user=1.25, unique=129
# [Adult + children s] [35] (Original-G2) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + children s Original-G2: avg/user=0.00, unique=0
# [Adult + children s] [35] (Original-AND) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + children s Original-AND: avg/user=0.00, unique=0
# [Adult + children s] [35] (Original-OR) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + children s Original-OR: avg/user=1.25, unique=129
# [Adult + children s] [15] (G1) forpair_Adult__Children_s_2u_pos5_neg1_OR_15recommendation.csv -> 2048 books -> Adult + children s G1: avg/user=0.51, unique=90
# [Adult + children s] [15] (G2) forpair_Adult__Children_s_2u_pos5_neg1_OR_15recommendation.csv -> 2048 books -> Adult + children s G2: avg/user=0.00, unique=0
# [Adult + children s] [15] (AND) forpair_Adult__Children_s_2u_pos5_neg1_OR_15recommendation.csv -> 2048 books -> Adult + children s AND: avg/user=0.00, unique=0
# [Adult + children s] [15] (OR) forpair_Adult__Children_s_2u_pos5_neg1_OR_15recommendation.csv -> 2048 books -> Adult + children s OR: avg/user=0.51, unique=90
# [Adult + children s] [15] (G1) forpair_Adult__Children_s_6u_pos5_neg1_OR_15recommendation.csv -> 1967 books -> Adult + children s G1: avg/user=0.73, unique=90
# [Adult + children s] [15] (G2) forpair_Adult__Children_s_6u_pos5_neg1_OR_15recommendation.csv -> 1967 books -> Adult + children s G2: avg/user=0.00, unique=0
# [Adult + children s] [15] (AND) forpair_Adult__Children_s_6u_pos5_neg1_OR_15recommendation.csv -> 1967 books -> Adult + children s AND: avg/user=0.00, unique=0
# [Adult + children s] [15] (OR) forpair_Adult__Children_s_6u_pos5_neg1_OR_15recommendation.csv -> 1967 books -> Adult + children s OR: avg/user=0.73, unique=90
# [Adult + children s] [15] (G1) forpair_Adult__Children_s_200u_pos5_neg1_OR_15recommendation.csv -> 2079 books -> Adult + children s G1: avg/user=0.84, unique=118
# [Adult + children s] [15] (G2) forpair_Adult__Children_s_200u_pos5_neg1_OR_15recommendation.csv -> 2079 books -> Adult + children s G2: avg/user=0.00, unique=0
# [Adult + children s] [15] (AND) forpair_Adult__Children_s_200u_pos5_neg1_OR_15recommendation.csv -> 2079 books -> Adult + children s AND: avg/user=0.00, unique=0
# [Adult + children s] [15] (OR) forpair_Adult__Children_s_200u_pos5_neg1_OR_15recommendation.csv -> 2079 books -> Adult + children s OR: avg/user=0.84, unique=118
# [Adult + children s] [25] (G1) forpair_Adult__Children_s_2u_pos5_neg1_OR_25recommendation.csv -> 2785 books -> Adult + children s G1: avg/user=0.81, unique=115
# [Adult + children s] [25] (G2) forpair_Adult__Children_s_2u_pos5_neg1_OR_25recommendation.csv -> 2785 books -> Adult + children s G2: avg/user=0.00, unique=0
# [Adult + children s] [25] (AND) forpair_Adult__Children_s_2u_pos5_neg1_OR_25recommendation.csv -> 2785 books -> Adult + children s AND: avg/user=0.00, unique=0
# [Adult + children s] [25] (OR) forpair_Adult__Children_s_2u_pos5_neg1_OR_25recommendation.csv -> 2785 books -> Adult + children s OR: avg/user=0.81, unique=115
# [Adult + children s] [25] (G1) forpair_Adult__Children_s_6u_pos5_neg1_OR_25recommendation.csv -> 2648 books -> Adult + children s G1: avg/user=1.21, unique=127
# [Adult + children s] [25] (G2) forpair_Adult__Children_s_6u_pos5_neg1_OR_25recommendation.csv -> 2648 books -> Adult + children s G2: avg/user=0.00, unique=0
# [Adult + children s] [25] (AND) forpair_Adult__Children_s_6u_pos5_neg1_OR_25recommendation.csv -> 2648 books -> Adult + children s AND: avg/user=0.00, unique=0
# [Adult + children s] [25] (OR) forpair_Adult__Children_s_6u_pos5_neg1_OR_25recommendation.csv -> 2648 books -> Adult + children s OR: avg/user=1.21, unique=127
# [Adult + children s] [25] (G1) forpair_Adult__Children_s_200u_pos5_neg1_OR_25recommendation.csv -> 2782 books -> Adult + children s G1: avg/user=1.37, unique=164
# [Adult + children s] [25] (G2) forpair_Adult__Children_s_200u_pos5_neg1_OR_25recommendation.csv -> 2782 books -> Adult + children s G2: avg/user=0.00, unique=0
# [Adult + children s] [25] (AND) forpair_Adult__Children_s_200u_pos5_neg1_OR_25recommendation.csv -> 2782 books -> Adult + children s AND: avg/user=0.00, unique=0
# [Adult + children s] [25] (OR) forpair_Adult__Children_s_200u_pos5_neg1_OR_25recommendation.csv -> 2782 books -> Adult + children s OR: avg/user=1.37, unique=164
# [Adult + children s] [35] (G1) forpair_Adult__Children_s_2u_pos5_neg1_OR_35recommendation.csv -> 3326 books -> Adult + children s G1: avg/user=1.11, unique=135
# [Adult + children s] [35] (G2) forpair_Adult__Children_s_2u_pos5_neg1_OR_35recommendation.csv -> 3326 books -> Adult + children s G2: avg/user=0.00, unique=0
# [Adult + children s] [35] (AND) forpair_Adult__Children_s_2u_pos5_neg1_OR_35recommendation.csv -> 3326 books -> Adult + children s AND: avg/user=0.00, unique=0
# [Adult + children s] [35] (OR) forpair_Adult__Children_s_2u_pos5_neg1_OR_35recommendation.csv -> 3326 books -> Adult + children s OR: avg/user=1.11, unique=135
# [Adult + children s] [35] (G1) forpair_Adult__Children_s_6u_pos5_neg1_OR_35recommendation.csv -> 3162 books -> Adult + children s G1: avg/user=1.69, unique=149
# [Adult + children s] [35] (G2) forpair_Adult__Children_s_6u_pos5_neg1_OR_35recommendation.csv -> 3162 books -> Adult + children s G2: avg/user=0.00, unique=0
# [Adult + children s] [35] (AND) forpair_Adult__Children_s_6u_pos5_neg1_OR_35recommendation.csv -> 3162 books -> Adult + children s AND: avg/user=0.00, unique=0
# [Adult + children s] [35] (OR) forpair_Adult__Children_s_6u_pos5_neg1_OR_35recommendation.csv -> 3162 books -> Adult + children s OR: avg/user=1.69, unique=149
# [Adult + children s] [35] (G1) forpair_Adult__Children_s_200u_pos5_neg1_OR_35recommendation.csv -> 3361 books -> Adult + children s G1: avg/user=1.90, unique=204
# [Adult + children s] [35] (G2) forpair_Adult__Children_s_200u_pos5_neg1_OR_35recommendation.csv -> 3361 books -> Adult + children s G2: avg/user=0.00, unique=0
# [Adult + children s] [35] (AND) forpair_Adult__Children_s_200u_pos5_neg1_OR_35recommendation.csv -> 3361 books -> Adult + children s AND: avg/user=0.00, unique=0
# [Adult + children s] [35] (OR) forpair_Adult__Children_s_200u_pos5_neg1_OR_35recommendation.csv -> 3361 books -> Adult + children s OR: avg/user=1.90, unique=204
# [OK][Adult + children s] Saved text:   /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__children_s_pair_explanation/explanation.txt
# [OK][Adult + children s] Saved tables: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__children_s_pair_explanation/per_book_ranking_pair.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__children_s_pair_explanation/per_book_ranking_g1.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__children_s_pair_explanation/per_book_ranking_g2.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__children_s_pair_explanation/per_book_ranking_or.csv
# [OK][Adult + children s] Saved figures: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__children_s_pair_explanation/adult_children_s__single_g1_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__children_s_pair_explanation/adult_children_s__single_g2_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__children_s_pair_explanation/adult_children_s__and_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__children_s_pair_explanation/adult_children_s__or_pos5.png
# [Adult + Classics] [15] (Original-G1) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Classics Original-G1: avg/user=0.60, unique=86
# [Adult + Classics] [15] (Original-G2) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Classics Original-G2: avg/user=0.89, unique=167
# [Adult + Classics] [15] (Original-AND) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Classics Original-AND: avg/user=0.00, unique=1
# [Adult + Classics] [15] (Original-OR) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Classics Original-OR: avg/user=1.49, unique=252
# [Adult + Classics] [25] (Original-G1) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Classics Original-G1: avg/user=0.94, unique=110
# [Adult + Classics] [25] (Original-G2) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Classics Original-G2: avg/user=1.60, unique=234
# [Adult + Classics] [25] (Original-AND) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Classics Original-AND: avg/user=0.00, unique=2
# [Adult + Classics] [25] (Original-OR) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Classics Original-OR: avg/user=2.54, unique=342
# [Adult + Classics] [35] (Original-G1) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Classics Original-G1: avg/user=1.25, unique=129
# [Adult + Classics] [35] (Original-G2) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Classics Original-G2: avg/user=2.34, unique=305
# [Adult + Classics] [35] (Original-AND) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Classics Original-AND: avg/user=0.00, unique=2
# [Adult + Classics] [35] (Original-OR) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Classics Original-OR: avg/user=3.58, unique=432
# [Adult + Classics] [15] (G1) forpair_Adult__Classics_2u_pos5_neg1_OR_15recommendation.csv -> 2030 books -> Adult + Classics G1: avg/user=0.50, unique=86
# [Adult + Classics] [15] (G2) forpair_Adult__Classics_2u_pos5_neg1_OR_15recommendation.csv -> 2030 books -> Adult + Classics G2: avg/user=1.31, unique=190
# [Adult + Classics] [15] (AND) forpair_Adult__Classics_2u_pos5_neg1_OR_15recommendation.csv -> 2030 books -> Adult + Classics AND: avg/user=0.00, unique=0
# [Adult + Classics] [15] (OR) forpair_Adult__Classics_2u_pos5_neg1_OR_15recommendation.csv -> 2030 books -> Adult + Classics OR: avg/user=1.81, unique=276
# [Adult + Classics] [15] (G1) forpair_Adult__Classics_6u_pos5_neg1_OR_15recommendation.csv -> 1980 books -> Adult + Classics G1: avg/user=0.64, unique=94
# [Adult + Classics] [15] (G2) forpair_Adult__Classics_6u_pos5_neg1_OR_15recommendation.csv -> 1980 books -> Adult + Classics G2: avg/user=1.98, unique=200
# [Adult + Classics] [15] (AND) forpair_Adult__Classics_6u_pos5_neg1_OR_15recommendation.csv -> 1980 books -> Adult + Classics AND: avg/user=0.00, unique=0
# [Adult + Classics] [15] (OR) forpair_Adult__Classics_6u_pos5_neg1_OR_15recommendation.csv -> 1980 books -> Adult + Classics OR: avg/user=2.62, unique=294
# [Adult + Classics] [15] (G1) forpair_Adult__Classics_200u_pos5_neg1_OR_15recommendation.csv -> 2080 books -> Adult + Classics G1: avg/user=0.69, unique=123
# [Adult + Classics] [15] (G2) forpair_Adult__Classics_200u_pos5_neg1_OR_15recommendation.csv -> 2080 books -> Adult + Classics G2: avg/user=3.33, unique=304
# [Adult + Classics] [15] (AND) forpair_Adult__Classics_200u_pos5_neg1_OR_15recommendation.csv -> 2080 books -> Adult + Classics AND: avg/user=0.00, unique=3
# [Adult + Classics] [15] (OR) forpair_Adult__Classics_200u_pos5_neg1_OR_15recommendation.csv -> 2080 books -> Adult + Classics OR: avg/user=4.02, unique=424
# [Adult + Classics] [25] (G1) forpair_Adult__Classics_2u_pos5_neg1_OR_25recommendation.csv -> 2746 books -> Adult + Classics G1: avg/user=0.80, unique=115
# [Adult + Classics] [25] (G2) forpair_Adult__Classics_2u_pos5_neg1_OR_25recommendation.csv -> 2746 books -> Adult + Classics G2: avg/user=2.19, unique=266
# [Adult + Classics] [25] (AND) forpair_Adult__Classics_2u_pos5_neg1_OR_25recommendation.csv -> 2746 books -> Adult + Classics AND: avg/user=0.00, unique=0
# [Adult + Classics] [25] (OR) forpair_Adult__Classics_2u_pos5_neg1_OR_25recommendation.csv -> 2746 books -> Adult + Classics OR: avg/user=2.99, unique=381
# [Adult + Classics] [25] (G1) forpair_Adult__Classics_6u_pos5_neg1_OR_25recommendation.csv -> 2652 books -> Adult + Classics G1: avg/user=1.06, unique=124
# [Adult + Classics] [25] (G2) forpair_Adult__Classics_6u_pos5_neg1_OR_25recommendation.csv -> 2652 books -> Adult + Classics G2: avg/user=3.45, unique=276
# [Adult + Classics] [25] (AND) forpair_Adult__Classics_6u_pos5_neg1_OR_25recommendation.csv -> 2652 books -> Adult + Classics AND: avg/user=0.00, unique=2
# [Adult + Classics] [25] (OR) forpair_Adult__Classics_6u_pos5_neg1_OR_25recommendation.csv -> 2652 books -> Adult + Classics OR: avg/user=4.51, unique=398
# [Adult + Classics] [25] (G1) forpair_Adult__Classics_200u_pos5_neg1_OR_25recommendation.csv -> 2734 books -> Adult + Classics G1: avg/user=1.15, unique=154
# [Adult + Classics] [25] (G2) forpair_Adult__Classics_200u_pos5_neg1_OR_25recommendation.csv -> 2734 books -> Adult + Classics G2: avg/user=5.33, unique=409
# [Adult + Classics] [25] (AND) forpair_Adult__Classics_200u_pos5_neg1_OR_25recommendation.csv -> 2734 books -> Adult + Classics AND: avg/user=0.00, unique=3
# [Adult + Classics] [25] (OR) forpair_Adult__Classics_200u_pos5_neg1_OR_25recommendation.csv -> 2734 books -> Adult + Classics OR: avg/user=6.48, unique=560
# [Adult + Classics] [35] (G1) forpair_Adult__Classics_2u_pos5_neg1_OR_35recommendation.csv -> 3309 books -> Adult + Classics G1: avg/user=1.09, unique=130
# [Adult + Classics] [35] (G2) forpair_Adult__Classics_2u_pos5_neg1_OR_35recommendation.csv -> 3309 books -> Adult + Classics G2: avg/user=3.08, unique=337
# [Adult + Classics] [35] (AND) forpair_Adult__Classics_2u_pos5_neg1_OR_35recommendation.csv -> 3309 books -> Adult + Classics AND: avg/user=0.00, unique=1
# [Adult + Classics] [35] (OR) forpair_Adult__Classics_2u_pos5_neg1_OR_35recommendation.csv -> 3309 books -> Adult + Classics OR: avg/user=4.17, unique=466
# [Adult + Classics] [35] (G1) forpair_Adult__Classics_6u_pos5_neg1_OR_35recommendation.csv -> 3189 books -> Adult + Classics G1: avg/user=1.46, unique=146
# [Adult + Classics] [35] (G2) forpair_Adult__Classics_6u_pos5_neg1_OR_35recommendation.csv -> 3189 books -> Adult + Classics G2: avg/user=4.90, unique=336
# [Adult + Classics] [35] (AND) forpair_Adult__Classics_6u_pos5_neg1_OR_35recommendation.csv -> 3189 books -> Adult + Classics AND: avg/user=0.00, unique=3
# [Adult + Classics] [35] (OR) forpair_Adult__Classics_6u_pos5_neg1_OR_35recommendation.csv -> 3189 books -> Adult + Classics OR: avg/user=6.36, unique=479
# [Adult + Classics] [35] (G1) forpair_Adult__Classics_200u_pos5_neg1_OR_35recommendation.csv -> 3300 books -> Adult + Classics G1: avg/user=1.62, unique=186
# [Adult + Classics] [35] (G2) forpair_Adult__Classics_200u_pos5_neg1_OR_35recommendation.csv -> 3300 books -> Adult + Classics G2: avg/user=7.27, unique=486
# [Adult + Classics] [35] (AND) forpair_Adult__Classics_200u_pos5_neg1_OR_35recommendation.csv -> 3300 books -> Adult + Classics AND: avg/user=0.00, unique=3
# [Adult + Classics] [35] (OR) forpair_Adult__Classics_200u_pos5_neg1_OR_35recommendation.csv -> 3300 books -> Adult + Classics OR: avg/user=8.88, unique=669
# [OK][Adult + Classics] Saved text:   /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Classics_pair_explanation/explanation.txt
# [OK][Adult + Classics] Saved tables: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Classics_pair_explanation/per_book_ranking_pair.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Classics_pair_explanation/per_book_ranking_g1.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Classics_pair_explanation/per_book_ranking_g2.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Classics_pair_explanation/per_book_ranking_or.csv
# [OK][Adult + Classics] Saved figures: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Classics_pair_explanation/adult_classics__single_g1_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Classics_pair_explanation/adult_classics__single_g2_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Classics_pair_explanation/adult_classics__and_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Classics_pair_explanation/adult_classics__or_pos5.png
# [Adult + Drama] [15] (Original-G1) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Drama Original-G1: avg/user=0.60, unique=86
# [Adult + Drama] [15] (Original-G2) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Drama Original-G2: avg/user=4.93, unique=592
# [Adult + Drama] [15] (Original-AND) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Drama Original-AND: avg/user=0.18, unique=31
# [Adult + Drama] [15] (Original-OR) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Drama Original-OR: avg/user=5.35, unique=647
# [Adult + Drama] [25] (Original-G1) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Drama Original-G1: avg/user=0.94, unique=110
# [Adult + Drama] [25] (Original-G2) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Drama Original-G2: avg/user=8.10, unique=790
# [Adult + Drama] [25] (Original-AND) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Drama Original-AND: avg/user=0.29, unique=42
# [Adult + Drama] [25] (Original-OR) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Drama Original-OR: avg/user=8.75, unique=858
# [Adult + Drama] [35] (Original-G1) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Drama Original-G1: avg/user=1.25, unique=129
# [Adult + Drama] [35] (Original-G2) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Drama Original-G2: avg/user=11.23, unique=970
# [Adult + Drama] [35] (Original-AND) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Drama Original-AND: avg/user=0.40, unique=50
# [Adult + Drama] [35] (Original-OR) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Drama Original-OR: avg/user=12.08, unique=1049
# [Adult + Drama] [15] (G1) forpair_Adult__Drama_2u_pos5_neg1_OR_15recommendation.csv -> 2039 books -> Adult + Drama G1: avg/user=0.50, unique=91
# [Adult + Drama] [15] (G2) forpair_Adult__Drama_2u_pos5_neg1_OR_15recommendation.csv -> 2039 books -> Adult + Drama G2: avg/user=5.11, unique=631
# [Adult + Drama] [15] (AND) forpair_Adult__Drama_2u_pos5_neg1_OR_15recommendation.csv -> 2039 books -> Adult + Drama AND: avg/user=0.13, unique=41
# [Adult + Drama] [15] (OR) forpair_Adult__Drama_2u_pos5_neg1_OR_15recommendation.csv -> 2039 books -> Adult + Drama OR: avg/user=5.49, unique=681
# [Adult + Drama] [15] (G1) forpair_Adult__Drama_6u_pos5_neg1_OR_15recommendation.csv -> 1977 books -> Adult + Drama G1: avg/user=0.69, unique=94
# [Adult + Drama] [15] (G2) forpair_Adult__Drama_6u_pos5_neg1_OR_15recommendation.csv -> 1977 books -> Adult + Drama G2: avg/user=5.32, unique=602
# [Adult + Drama] [15] (AND) forpair_Adult__Drama_6u_pos5_neg1_OR_15recommendation.csv -> 1977 books -> Adult + Drama AND: avg/user=0.28, unique=42
# [Adult + Drama] [15] (OR) forpair_Adult__Drama_6u_pos5_neg1_OR_15recommendation.csv -> 1977 books -> Adult + Drama OR: avg/user=5.73, unique=654
# [Adult + Drama] [15] (G1) forpair_Adult__Drama_200u_pos5_neg1_OR_15recommendation.csv -> 2087 books -> Adult + Drama G1: avg/user=0.46, unique=79
# [Adult + Drama] [15] (G2) forpair_Adult__Drama_200u_pos5_neg1_OR_15recommendation.csv -> 2087 books -> Adult + Drama G2: avg/user=6.08, unique=638
# [Adult + Drama] [15] (AND) forpair_Adult__Drama_200u_pos5_neg1_OR_15recommendation.csv -> 2087 books -> Adult + Drama AND: avg/user=0.17, unique=29
# [Adult + Drama] [15] (OR) forpair_Adult__Drama_200u_pos5_neg1_OR_15recommendation.csv -> 2087 books -> Adult + Drama OR: avg/user=6.37, unique=688
# [Adult + Drama] [25] (G1) forpair_Adult__Drama_2u_pos5_neg1_OR_25recommendation.csv -> 2739 books -> Adult + Drama G1: avg/user=0.80, unique=108
# [Adult + Drama] [25] (G2) forpair_Adult__Drama_2u_pos5_neg1_OR_25recommendation.csv -> 2739 books -> Adult + Drama G2: avg/user=8.35, unique=815
# [Adult + Drama] [25] (AND) forpair_Adult__Drama_2u_pos5_neg1_OR_25recommendation.csv -> 2739 books -> Adult + Drama AND: avg/user=0.24, unique=47
# [Adult + Drama] [25] (OR) forpair_Adult__Drama_2u_pos5_neg1_OR_25recommendation.csv -> 2739 books -> Adult + Drama OR: avg/user=8.91, unique=876
# [Adult + Drama] [25] (G1) forpair_Adult__Drama_6u_pos5_neg1_OR_25recommendation.csv -> 2660 books -> Adult + Drama G1: avg/user=1.09, unique=115
# [Adult + Drama] [25] (G2) forpair_Adult__Drama_6u_pos5_neg1_OR_25recommendation.csv -> 2660 books -> Adult + Drama G2: avg/user=8.85, unique=817
# [Adult + Drama] [25] (AND) forpair_Adult__Drama_6u_pos5_neg1_OR_25recommendation.csv -> 2660 books -> Adult + Drama AND: avg/user=0.44, unique=50
# [Adult + Drama] [25] (OR) forpair_Adult__Drama_6u_pos5_neg1_OR_25recommendation.csv -> 2660 books -> Adult + Drama OR: avg/user=9.50, unique=882
# [Adult + Drama] [25] (G1) forpair_Adult__Drama_200u_pos5_neg1_OR_25recommendation.csv -> 2803 books -> Adult + Drama G1: avg/user=0.73, unique=104
# [Adult + Drama] [25] (G2) forpair_Adult__Drama_200u_pos5_neg1_OR_25recommendation.csv -> 2803 books -> Adult + Drama G2: avg/user=10.00, unique=869
# [Adult + Drama] [25] (AND) forpair_Adult__Drama_200u_pos5_neg1_OR_25recommendation.csv -> 2803 books -> Adult + Drama AND: avg/user=0.28, unique=40
# [Adult + Drama] [25] (OR) forpair_Adult__Drama_200u_pos5_neg1_OR_25recommendation.csv -> 2803 books -> Adult + Drama OR: avg/user=10.45, unique=933
# [Adult + Drama] [35] (G1) forpair_Adult__Drama_2u_pos5_neg1_OR_35recommendation.csv -> 3336 books -> Adult + Drama G1: avg/user=1.08, unique=128
# [Adult + Drama] [35] (G2) forpair_Adult__Drama_2u_pos5_neg1_OR_35recommendation.csv -> 3336 books -> Adult + Drama G2: avg/user=11.57, unique=985
# [Adult + Drama] [35] (AND) forpair_Adult__Drama_2u_pos5_neg1_OR_35recommendation.csv -> 3336 books -> Adult + Drama AND: avg/user=0.36, unique=54
# [Adult + Drama] [35] (OR) forpair_Adult__Drama_2u_pos5_neg1_OR_35recommendation.csv -> 3336 books -> Adult + Drama OR: avg/user=12.29, unique=1059
# [Adult + Drama] [35] (G1) forpair_Adult__Drama_6u_pos5_neg1_OR_35recommendation.csv -> 3200 books -> Adult + Drama G1: avg/user=1.47, unique=143
# [Adult + Drama] [35] (G2) forpair_Adult__Drama_6u_pos5_neg1_OR_35recommendation.csv -> 3200 books -> Adult + Drama G2: avg/user=12.36, unique=977
# [Adult + Drama] [35] (AND) forpair_Adult__Drama_6u_pos5_neg1_OR_35recommendation.csv -> 3200 books -> Adult + Drama AND: avg/user=0.60, unique=58
# [Adult + Drama] [35] (OR) forpair_Adult__Drama_6u_pos5_neg1_OR_35recommendation.csv -> 3200 books -> Adult + Drama OR: avg/user=13.23, unique=1062
# [Adult + Drama] [35] (G1) forpair_Adult__Drama_200u_pos5_neg1_OR_35recommendation.csv -> 3320 books -> Adult + Drama G1: avg/user=0.98, unique=124
# [Adult + Drama] [35] (G2) forpair_Adult__Drama_200u_pos5_neg1_OR_35recommendation.csv -> 3320 books -> Adult + Drama G2: avg/user=13.86, unique=1051
# [Adult + Drama] [35] (AND) forpair_Adult__Drama_200u_pos5_neg1_OR_35recommendation.csv -> 3320 books -> Adult + Drama AND: avg/user=0.39, unique=47
# [Adult + Drama] [35] (OR) forpair_Adult__Drama_200u_pos5_neg1_OR_35recommendation.csv -> 3320 books -> Adult + Drama OR: avg/user=14.45, unique=1128
# [OK][Adult + Drama] Saved text:   /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Drama_pair_explanation/explanation.txt
# [OK][Adult + Drama] Saved tables: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Drama_pair_explanation/per_book_ranking_pair.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Drama_pair_explanation/per_book_ranking_g1.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Drama_pair_explanation/per_book_ranking_g2.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Drama_pair_explanation/per_book_ranking_or.csv
# [OK][Adult + Drama] Saved figures: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Drama_pair_explanation/adult_drama__single_g1_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Drama_pair_explanation/adult_drama__single_g2_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Drama_pair_explanation/adult_drama__and_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Drama_pair_explanation/adult_drama__or_pos5.png
# [Adult + Fantasy] [15] (Original-G1) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Fantasy Original-G1: avg/user=0.60, unique=86
# [Adult + Fantasy] [15] (Original-G2) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Fantasy Original-G2: avg/user=3.20, unique=504
# [Adult + Fantasy] [15] (Original-AND) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Fantasy Original-AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [15] (Original-OR) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Fantasy Original-OR: avg/user=3.81, unique=590
# [Adult + Fantasy] [25] (Original-G1) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Fantasy Original-G1: avg/user=0.94, unique=110
# [Adult + Fantasy] [25] (Original-G2) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Fantasy Original-G2: avg/user=5.65, unique=676
# [Adult + Fantasy] [25] (Original-AND) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Fantasy Original-AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [25] (Original-OR) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Fantasy Original-OR: avg/user=6.59, unique=786
# [Adult + Fantasy] [35] (Original-G1) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Fantasy Original-G1: avg/user=1.25, unique=129
# [Adult + Fantasy] [35] (Original-G2) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Fantasy Original-G2: avg/user=8.15, unique=809
# [Adult + Fantasy] [35] (Original-AND) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Fantasy Original-AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [35] (Original-OR) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Fantasy Original-OR: avg/user=9.40, unique=938
# [Adult + Fantasy] [15] (G1) forpair_Adult__Fantasy_2u_pos5_neg1_OR_15recommendation.csv -> 2030 books -> Adult + Fantasy G1: avg/user=0.51, unique=94
# [Adult + Fantasy] [15] (G2) forpair_Adult__Fantasy_2u_pos5_neg1_OR_15recommendation.csv -> 2030 books -> Adult + Fantasy G2: avg/user=3.74, unique=516
# [Adult + Fantasy] [15] (AND) forpair_Adult__Fantasy_2u_pos5_neg1_OR_15recommendation.csv -> 2030 books -> Adult + Fantasy AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [15] (OR) forpair_Adult__Fantasy_2u_pos5_neg1_OR_15recommendation.csv -> 2030 books -> Adult + Fantasy OR: avg/user=4.25, unique=610
# [Adult + Fantasy] [15] (G1) forpair_Adult__Fantasy_6u_pos5_neg1_OR_15recommendation.csv -> 1950 books -> Adult + Fantasy G1: avg/user=0.64, unique=94
# [Adult + Fantasy] [15] (G2) forpair_Adult__Fantasy_6u_pos5_neg1_OR_15recommendation.csv -> 1950 books -> Adult + Fantasy G2: avg/user=4.81, unique=522
# [Adult + Fantasy] [15] (AND) forpair_Adult__Fantasy_6u_pos5_neg1_OR_15recommendation.csv -> 1950 books -> Adult + Fantasy AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [15] (OR) forpair_Adult__Fantasy_6u_pos5_neg1_OR_15recommendation.csv -> 1950 books -> Adult + Fantasy OR: avg/user=5.45, unique=616
# [Adult + Fantasy] [15] (G1) forpair_Adult__Fantasy_200u_pos5_neg1_OR_15recommendation.csv -> 2084 books -> Adult + Fantasy G1: avg/user=1.00, unique=112
# [Adult + Fantasy] [15] (G2) forpair_Adult__Fantasy_200u_pos5_neg1_OR_15recommendation.csv -> 2084 books -> Adult + Fantasy G2: avg/user=5.12, unique=576
# [Adult + Fantasy] [15] (AND) forpair_Adult__Fantasy_200u_pos5_neg1_OR_15recommendation.csv -> 2084 books -> Adult + Fantasy AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [15] (OR) forpair_Adult__Fantasy_200u_pos5_neg1_OR_15recommendation.csv -> 2084 books -> Adult + Fantasy OR: avg/user=6.11, unique=688
# [Adult + Fantasy] [25] (G1) forpair_Adult__Fantasy_2u_pos5_neg1_OR_25recommendation.csv -> 2739 books -> Adult + Fantasy G1: avg/user=0.81, unique=117
# [Adult + Fantasy] [25] (G2) forpair_Adult__Fantasy_2u_pos5_neg1_OR_25recommendation.csv -> 2739 books -> Adult + Fantasy G2: avg/user=6.57, unique=692
# [Adult + Fantasy] [25] (AND) forpair_Adult__Fantasy_2u_pos5_neg1_OR_25recommendation.csv -> 2739 books -> Adult + Fantasy AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [25] (OR) forpair_Adult__Fantasy_2u_pos5_neg1_OR_25recommendation.csv -> 2739 books -> Adult + Fantasy OR: avg/user=7.39, unique=809
# [Adult + Fantasy] [25] (G1) forpair_Adult__Fantasy_6u_pos5_neg1_OR_25recommendation.csv -> 2612 books -> Adult + Fantasy G1: avg/user=1.06, unique=122
# [Adult + Fantasy] [25] (G2) forpair_Adult__Fantasy_6u_pos5_neg1_OR_25recommendation.csv -> 2612 books -> Adult + Fantasy G2: avg/user=8.07, unique=689
# [Adult + Fantasy] [25] (AND) forpair_Adult__Fantasy_6u_pos5_neg1_OR_25recommendation.csv -> 2612 books -> Adult + Fantasy AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [25] (OR) forpair_Adult__Fantasy_6u_pos5_neg1_OR_25recommendation.csv -> 2612 books -> Adult + Fantasy OR: avg/user=9.13, unique=811
# [Adult + Fantasy] [25] (G1) forpair_Adult__Fantasy_200u_pos5_neg1_OR_25recommendation.csv -> 2768 books -> Adult + Fantasy G1: avg/user=1.55, unique=141
# [Adult + Fantasy] [25] (G2) forpair_Adult__Fantasy_200u_pos5_neg1_OR_25recommendation.csv -> 2768 books -> Adult + Fantasy G2: avg/user=8.65, unique=767
# [Adult + Fantasy] [25] (AND) forpair_Adult__Fantasy_200u_pos5_neg1_OR_25recommendation.csv -> 2768 books -> Adult + Fantasy AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [25] (OR) forpair_Adult__Fantasy_200u_pos5_neg1_OR_25recommendation.csv -> 2768 books -> Adult + Fantasy OR: avg/user=10.20, unique=908
# [Adult + Fantasy] [35] (G1) forpair_Adult__Fantasy_2u_pos5_neg1_OR_35recommendation.csv -> 3301 books -> Adult + Fantasy G1: avg/user=1.11, unique=133
# [Adult + Fantasy] [35] (G2) forpair_Adult__Fantasy_2u_pos5_neg1_OR_35recommendation.csv -> 3301 books -> Adult + Fantasy G2: avg/user=9.41, unique=819
# [Adult + Fantasy] [35] (AND) forpair_Adult__Fantasy_2u_pos5_neg1_OR_35recommendation.csv -> 3301 books -> Adult + Fantasy AND: avg/user=0.00, unique=1
# [Adult + Fantasy] [35] (OR) forpair_Adult__Fantasy_2u_pos5_neg1_OR_35recommendation.csv -> 3301 books -> Adult + Fantasy OR: avg/user=10.52, unique=951
# [Adult + Fantasy] [35] (G1) forpair_Adult__Fantasy_6u_pos5_neg1_OR_35recommendation.csv -> 3143 books -> Adult + Fantasy G1: avg/user=1.47, unique=145
# [Adult + Fantasy] [35] (G2) forpair_Adult__Fantasy_6u_pos5_neg1_OR_35recommendation.csv -> 3143 books -> Adult + Fantasy G2: avg/user=11.25, unique=813
# [Adult + Fantasy] [35] (AND) forpair_Adult__Fantasy_6u_pos5_neg1_OR_35recommendation.csv -> 3143 books -> Adult + Fantasy AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [35] (OR) forpair_Adult__Fantasy_6u_pos5_neg1_OR_35recommendation.csv -> 3143 books -> Adult + Fantasy OR: avg/user=12.72, unique=958
# [Adult + Fantasy] [35] (G1) forpair_Adult__Fantasy_200u_pos5_neg1_OR_35recommendation.csv -> 3393 books -> Adult + Fantasy G1: avg/user=2.08, unique=165
# [Adult + Fantasy] [35] (G2) forpair_Adult__Fantasy_200u_pos5_neg1_OR_35recommendation.csv -> 3393 books -> Adult + Fantasy G2: avg/user=12.16, unique=918
# [Adult + Fantasy] [35] (AND) forpair_Adult__Fantasy_200u_pos5_neg1_OR_35recommendation.csv -> 3393 books -> Adult + Fantasy AND: avg/user=0.00, unique=0
# [Adult + Fantasy] [35] (OR) forpair_Adult__Fantasy_200u_pos5_neg1_OR_35recommendation.csv -> 3393 books -> Adult + Fantasy OR: avg/user=14.24, unique=1083
# [OK][Adult + Fantasy] Saved text:   /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Fantasy_pair_explanation/explanation.txt
# [OK][Adult + Fantasy] Saved tables: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Fantasy_pair_explanation/per_book_ranking_pair.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Fantasy_pair_explanation/per_book_ranking_g1.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Fantasy_pair_explanation/per_book_ranking_g2.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Fantasy_pair_explanation/per_book_ranking_or.csv
# [OK][Adult + Fantasy] Saved figures: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Fantasy_pair_explanation/adult_fantasy__single_g1_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Fantasy_pair_explanation/adult_fantasy__single_g2_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Fantasy_pair_explanation/adult_fantasy__and_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adult__Fantasy_pair_explanation/adult_fantasy__or_pos5.png
# [Adult + Historical] [15] (Original-G1) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Historical Original-G1: avg/user=0.60, unique=86
# [Adult + Historical] [15] (Original-G2) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Historical Original-G2: avg/user=1.07, unique=151
# [Adult + Historical] [15] (Original-AND) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Historical Original-AND: avg/user=0.00, unique=0
# [Adult + Historical] [15] (Original-OR) ORIGINAL_15recommendation.csv -> 2041 books -> Adult + Historical Original-OR: avg/user=1.67, unique=237
# [Adult + Historical] [25] (Original-G1) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Historical Original-G1: avg/user=0.94, unique=110
# [Adult + Historical] [25] (Original-G2) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Historical Original-G2: avg/user=1.89, unique=218
# [Adult + Historical] [25] (Original-AND) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Historical Original-AND: avg/user=0.00, unique=0
# [Adult + Historical] [25] (Original-OR) ORIGINAL_25recommendation.csv -> 2771 books -> Adult + Historical Original-OR: avg/user=2.83, unique=328
# [Adult + Historical] [35] (Original-G1) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Historical Original-G1: avg/user=1.25, unique=129
# [Adult + Historical] [35] (Original-G2) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Historical Original-G2: avg/user=2.71, unique=284
# [Adult + Historical] [35] (Original-AND) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Historical Original-AND: avg/user=0.00, unique=1
# [Adult + Historical] [35] (Original-OR) ORIGINAL_35recommendation.csv -> 3366 books -> Adult + Historical Original-OR: avg/user=3.96, unique=412
# [Adult + Historical] [15] (G1) forpair_Adult__Historical_2u_pos5_neg1_OR_15recommendation.csv -> 2043 books -> Adult + Historical G1: avg/user=0.50, unique=89
# [Adult + Historical] [15] (G2) forpair_Adult__Historical_2u_pos5_neg1_OR_15recommendation.csv -> 2043 books -> Adult + Historical G2: avg/user=1.29, unique=183
# [Adult + Historical] [15] (AND) forpair_Adult__Historical_2u_pos5_neg1_OR_15recommendation.csv -> 2043 books -> Adult + Historical AND: avg/user=0.00, unique=2
# [Adult + Historical] [15] (OR) forpair_Adult__Historical_2u_pos5_neg1_OR_15recommendation.csv -> 2043 books -> Adult + Historical OR: avg/user=1.80, unique=270
# [Adult + Historical] [15] (G1) forpair_Adult__Historical_6u_pos5_neg1_OR_15recommendation.csv -> 2000 books -> Adult + Historical G1: avg/user=0.76, unique=101
# [Adult + Historical] [15] (G2) forpair_Adult__Historical_6u_pos5_neg1_OR_15recommendation.csv -> 2000 books -> Adult + Historical G2: avg/user=2.25, unique=189
# [Adult + Historical] [15] (AND) forpair_Adult__Historical_6u_pos5_neg1_OR_15recommendation.csv -> 2000 books -> Adult + Historical AND: avg/user=0.05, unique=3
# [Adult + Historical] [15] (OR) forpair_Adult__Historical_6u_pos5_neg1_OR_15recommendation.csv -> 2000 books -> Adult + Historical OR: avg/user=2.97, unique=287
# [Adult + Historical] [15] (G1) forpair_Adult__Historical_200u_pos5_neg1_OR_15recommendation.csv -> 2060 books -> Adult + Historical G1: avg/user=0.78, unique=118
# [Adult + Historical] [15] (G2) forpair_Adult__Historical_200u_pos5_neg1_OR_15recommendation.csv -> 2060 books -> Adult + Historical G2: avg/user=2.71, unique=289
# [Adult + Historical] [15] (AND) forpair_Adult__Historical_200u_pos5_neg1_OR_15recommendation.csv -> 2060 books -> Adult + Historical AND: avg/user=0.02, unique=2
# [Adult + Historical] [15] (OR) forpair_Adult__Historical_200u_pos5_neg1_OR_15recommendation.csv -> 2060 books -> Adult + Historical OR: avg/user=3.48, unique=405
# [Adult + Historical] [25] (G1) forpair_Adult__Historical_2u_pos5_neg1_OR_25recommendation.csv -> 2747 books -> Adult + Historical G1: avg/user=0.81, unique=114
# [Adult + Historical] [25] (G2) forpair_Adult__Historical_2u_pos5_neg1_OR_25recommendation.csv -> 2747 books -> Adult + Historical G2: avg/user=2.21, unique=250
# [Adult + Historical] [25] (AND) forpair_Adult__Historical_2u_pos5_neg1_OR_25recommendation.csv -> 2747 books -> Adult + Historical AND: avg/user=0.00, unique=2
# [Adult + Historical] [25] (OR) forpair_Adult__Historical_2u_pos5_neg1_OR_25recommendation.csv -> 2747 books -> Adult + Historical OR: avg/user=3.01, unique=362
# [Adult + Historical] [25] (G1) forpair_Adult__Historical_6u_pos5_neg1_OR_25recommendation.csv -> 2686 books -> Adult + Historical G1: avg/user=1.25, unique=129
# ...
# [Adventure + Horror] [35] (G1) forpair_Adventure__Horror_200u_pos5_neg1_OR_35recommendation.csv -> 3506 books -> Adventure + Horror G1: avg/user=9.90, unique=784
# [Adventure + Horror] [35] (G2) forpair_Adventure__Horror_200u_pos5_neg1_OR_35recommendation.csv -> 3506 books -> Adventure + Horror G2: avg/user=3.83, unique=336
# [Adventure + Horror] [35] (AND) forpair_Adventure__Horror_200u_pos5_neg1_OR_35recommendation.csv -> 3506 books -> Adventure + Horror AND: avg/user=0.04, unique=2
# [Adventure + Horror] [35] (OR) forpair_Adventure__Horror_200u_pos5_neg1_OR_35recommendation.csv -> 3506 books -> Adventure + Horror OR: avg/user=13.69, unique=1118
# [OK][Adventure + Horror] Saved text:   /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Horror_pair_explanation/explanation.txt
# [OK][Adventure + Horror] Saved tables: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Horror_pair_explanation/per_book_ranking_pair.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Horror_pair_explanation/per_book_ranking_g1.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Horror_pair_explanation/per_book_ranking_g2.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Horror_pair_explanation/per_book_ranking_or.csv
# [OK][Adventure + Horror] Saved figures: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Horror_pair_explanation/adventure_horror__single_g1_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Horror_pair_explanation/adventure_horror__single_g2_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Horror_pair_explanation/adventure_horror__and_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Horror_pair_explanation/adventure_horror__or_pos5.png
# [Adventure + Mystery] [15] (Original-G1) ORIGINAL_15recommendation.csv -> 2041 books -> Adventure + Mystery Original-G1: avg/user=2.87, unique=398
# [Adventure + Mystery] [15] (Original-G2) ORIGINAL_15recommendation.csv -> 2041 books -> Adventure + Mystery Original-G2: avg/user=3.80, unique=438
# [Adventure + Mystery] [15] (Original-AND) ORIGINAL_15recommendation.csv -> 2041 books -> Adventure + Mystery Original-AND: avg/user=0.42, unique=13
# [Adventure + Mystery] [15] (Original-OR) ORIGINAL_15recommendation.csv -> 2041 books -> Adventure + Mystery Original-OR: avg/user=6.25, unique=823
# [Adventure + Mystery] [25] (Original-G1) ORIGINAL_25recommendation.csv -> 2771 books -> Adventure + Mystery Original-G1: avg/user=4.90, unique=549
# [Adventure + Mystery] [25] (Original-G2) ORIGINAL_25recommendation.csv -> 2771 books -> Adventure + Mystery Original-G2: avg/user=6.12, unique=606
# [Adventure + Mystery] [25] (Original-AND) ORIGINAL_25recommendation.csv -> 2771 books -> Adventure + Mystery Original-AND: avg/user=0.53, unique=21
# [Adventure + Mystery] [25] (Original-OR) ORIGINAL_25recommendation.csv -> 2771 books -> Adventure + Mystery Original-OR: avg/user=10.48, unique=1134
# [Adventure + Mystery] [35] (Original-G1) ORIGINAL_35recommendation.csv -> 3366 books -> Adventure + Mystery Original-G1: avg/user=6.99, unique=663
# [Adventure + Mystery] [35] (Original-G2) ORIGINAL_35recommendation.csv -> 3366 books -> Adventure + Mystery Original-G2: avg/user=8.36, unique=732
# [Adventure + Mystery] [35] (Original-AND) ORIGINAL_35recommendation.csv -> 3366 books -> Adventure + Mystery Original-AND: avg/user=0.63, unique=26
# [Adventure + Mystery] [35] (Original-OR) ORIGINAL_35recommendation.csv -> 3366 books -> Adventure + Mystery Original-OR: avg/user=14.72, unique=1369
# [Adventure + Mystery] [15] (G1) forpair_Adventure__Mystery_2u_pos5_neg1_OR_15recommendation.csv -> 2052 books -> Adventure + Mystery G1: avg/user=2.85, unique=398
# [Adventure + Mystery] [15] (G2) forpair_Adventure__Mystery_2u_pos5_neg1_OR_15recommendation.csv -> 2052 books -> Adventure + Mystery G2: avg/user=3.39, unique=461
# [Adventure + Mystery] [15] (AND) forpair_Adventure__Mystery_2u_pos5_neg1_OR_15recommendation.csv -> 2052 books -> Adventure + Mystery AND: avg/user=0.20, unique=17
# [Adventure + Mystery] [15] (OR) forpair_Adventure__Mystery_2u_pos5_neg1_OR_15recommendation.csv -> 2052 books -> Adventure + Mystery OR: avg/user=6.04, unique=842
# [Adventure + Mystery] [15] (G1) forpair_Adventure__Mystery_6u_pos5_neg1_OR_15recommendation.csv -> 1951 books -> Adventure + Mystery G1: avg/user=3.27, unique=403
# [Adventure + Mystery] [15] (G2) forpair_Adventure__Mystery_6u_pos5_neg1_OR_15recommendation.csv -> 1951 books -> Adventure + Mystery G2: avg/user=3.78, unique=446
# [Adventure + Mystery] [15] (AND) forpair_Adventure__Mystery_6u_pos5_neg1_OR_15recommendation.csv -> 1951 books -> Adventure + Mystery AND: avg/user=0.16, unique=14
# [Adventure + Mystery] [15] (OR) forpair_Adventure__Mystery_6u_pos5_neg1_OR_15recommendation.csv -> 1951 books -> Adventure + Mystery OR: avg/user=6.88, unique=835
# [Adventure + Mystery] [15] (G1) forpair_Adventure__Mystery_200u_pos5_neg1_OR_15recommendation.csv -> 2100 books -> Adventure + Mystery G1: avg/user=2.96, unique=423
# [Adventure + Mystery] [15] (G2) forpair_Adventure__Mystery_200u_pos5_neg1_OR_15recommendation.csv -> 2100 books -> Adventure + Mystery G2: avg/user=3.35, unique=478
# [Adventure + Mystery] [15] (AND) forpair_Adventure__Mystery_200u_pos5_neg1_OR_15recommendation.csv -> 2100 books -> Adventure + Mystery AND: avg/user=0.21, unique=14
# [Adventure + Mystery] [15] (OR) forpair_Adventure__Mystery_200u_pos5_neg1_OR_15recommendation.csv -> 2100 books -> Adventure + Mystery OR: avg/user=6.09, unique=887
# [Adventure + Mystery] [25] (G1) forpair_Adventure__Mystery_2u_pos5_neg1_OR_25recommendation.csv -> 2737 books -> Adventure + Mystery G1: avg/user=5.07, unique=552
# [Adventure + Mystery] [25] (G2) forpair_Adventure__Mystery_2u_pos5_neg1_OR_25recommendation.csv -> 2737 books -> Adventure + Mystery G2: avg/user=5.58, unique=598
# [Adventure + Mystery] [25] (AND) forpair_Adventure__Mystery_2u_pos5_neg1_OR_25recommendation.csv -> 2737 books -> Adventure + Mystery AND: avg/user=0.31, unique=20
# [Adventure + Mystery] [25] (OR) forpair_Adventure__Mystery_2u_pos5_neg1_OR_25recommendation.csv -> 2737 books -> Adventure + Mystery OR: avg/user=10.34, unique=1130
# [Adventure + Mystery] [25] (G1) forpair_Adventure__Mystery_6u_pos5_neg1_OR_25recommendation.csv -> 2594 books -> Adventure + Mystery G1: avg/user=5.70, unique=533
# [Adventure + Mystery] [25] (G2) forpair_Adventure__Mystery_6u_pos5_neg1_OR_25recommendation.csv -> 2594 books -> Adventure + Mystery G2: avg/user=6.14, unique=597
# [Adventure + Mystery] [25] (AND) forpair_Adventure__Mystery_6u_pos5_neg1_OR_25recommendation.csv -> 2594 books -> Adventure + Mystery AND: avg/user=0.26, unique=16
# [Adventure + Mystery] [25] (OR) forpair_Adventure__Mystery_6u_pos5_neg1_OR_25recommendation.csv -> 2594 books -> Adventure + Mystery OR: avg/user=11.58, unique=1114
# [Adventure + Mystery] [25] (G1) forpair_Adventure__Mystery_200u_pos5_neg1_OR_25recommendation.csv -> 2832 books -> Adventure + Mystery G1: avg/user=5.21, unique=582
# [Adventure + Mystery] [25] (G2) forpair_Adventure__Mystery_200u_pos5_neg1_OR_25recommendation.csv -> 2832 books -> Adventure + Mystery G2: avg/user=5.67, unique=648
# [Adventure + Mystery] [25] (AND) forpair_Adventure__Mystery_200u_pos5_neg1_OR_25recommendation.csv -> 2832 books -> Adventure + Mystery AND: avg/user=0.31, unique=23
# [Adventure + Mystery] [25] (OR) forpair_Adventure__Mystery_200u_pos5_neg1_OR_25recommendation.csv -> 2832 books -> Adventure + Mystery OR: avg/user=10.57, unique=1207
# [Adventure + Mystery] [35] (G1) forpair_Adventure__Mystery_2u_pos5_neg1_OR_35recommendation.csv -> 3329 books -> Adventure + Mystery G1: avg/user=7.34, unique=676
# [Adventure + Mystery] [35] (G2) forpair_Adventure__Mystery_2u_pos5_neg1_OR_35recommendation.csv -> 3329 books -> Adventure + Mystery G2: avg/user=7.74, unique=724
# [Adventure + Mystery] [35] (AND) forpair_Adventure__Mystery_2u_pos5_neg1_OR_35recommendation.csv -> 3329 books -> Adventure + Mystery AND: avg/user=0.41, unique=23
# [Adventure + Mystery] [35] (OR) forpair_Adventure__Mystery_2u_pos5_neg1_OR_35recommendation.csv -> 3329 books -> Adventure + Mystery OR: avg/user=14.67, unique=1377
# [Adventure + Mystery] [35] (G1) forpair_Adventure__Mystery_6u_pos5_neg1_OR_35recommendation.csv -> 3158 books -> Adventure + Mystery G1: avg/user=8.12, unique=642
# [Adventure + Mystery] [35] (G2) forpair_Adventure__Mystery_6u_pos5_neg1_OR_35recommendation.csv -> 3158 books -> Adventure + Mystery G2: avg/user=8.47, unique=721
# [Adventure + Mystery] [35] (AND) forpair_Adventure__Mystery_6u_pos5_neg1_OR_35recommendation.csv -> 3158 books -> Adventure + Mystery AND: avg/user=0.36, unique=19
# [Adventure + Mystery] [35] (OR) forpair_Adventure__Mystery_6u_pos5_neg1_OR_35recommendation.csv -> 3158 books -> Adventure + Mystery OR: avg/user=16.24, unique=1344
# [Adventure + Mystery] [35] (G1) forpair_Adventure__Mystery_200u_pos5_neg1_OR_35recommendation.csv -> 3469 books -> Adventure + Mystery G1: avg/user=7.51, unique=693
# [Adventure + Mystery] [35] (G2) forpair_Adventure__Mystery_200u_pos5_neg1_OR_35recommendation.csv -> 3469 books -> Adventure + Mystery G2: avg/user=8.03, unique=799
# [Adventure + Mystery] [35] (AND) forpair_Adventure__Mystery_200u_pos5_neg1_OR_35recommendation.csv -> 3469 books -> Adventure + Mystery AND: avg/user=0.39, unique=29
# [Adventure + Mystery] [35] (OR) forpair_Adventure__Mystery_200u_pos5_neg1_OR_35recommendation.csv -> 3469 books -> Adventure + Mystery OR: avg/user=15.15, unique=1463
# [OK][Adventure + Mystery] Saved text:   /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Mystery_pair_explanation/explanation.txt
# [OK][Adventure + Mystery] Saved tables: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Mystery_pair_explanation/per_book_ranking_pair.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Mystery_pair_explanation/per_book_ranking_g1.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Mystery_pair_explanation/per_book_ranking_g2.csv, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Mystery_pair_explanation/per_book_ranking_or.csv
# [OK][Adventure + Mystery] Saved figures: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Mystery_pair_explanation/adventure_mystery__single_g1_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Mystery_pair_explanation/adventure_mystery__single_g2_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Mystery_pair_explanation/adventure_mystery__and_pos5.png, /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/1028/result/5_pair/Adventure__Mystery_pair_explanation/adventure_mystery__or_pos5.png
# [Adventure + Nonfiction] [15] (Original-G1) ORIGINAL_15recommendation.csv -> 2041 books -> Adventure + Nonfiction Original-G1: avg/user=2.87, unique=398
# [Adventure + Nonfiction] [15] (Original-G2) ORIGINAL_15recommendation.csv -> 2041 books -> Adventure + Nonfiction Original-G2: avg/user=2.22, unique=249
# [Adventure + Nonfiction] [15] (Original-AND) ORIGINAL_15recommendation.csv -> 2041 books -> Adventure + Nonfiction Original-AND: avg/user=0.02, unique=11
# [Adventure + Nonfiction] [15] (Original-OR) ORIGINAL_15recommendation.csv -> 2041 books -> Adventure + Nonfiction Original-OR: avg/user=5.06, unique=636
# [Adventure + Nonfiction] [25] (Original-G1) ORIGINAL_25recommendation.csv -> 2771 books -> Adventure + Nonfiction Original-G1: avg/user=4.90, unique=549
# [Adventure + Nonfiction] [25] (Original-G2) ORIGINAL_25recommendation.csv -> 2771 books -> Adventure + Nonfiction Original-G2: avg/user=3.46, unique=317
# [Adventure + Nonfiction] [25] (Original-AND) ORIGINAL_25recommendation.csv -> 2771 books -> Adventure + Nonfiction Original-AND: avg/user=0.05, unique=15
# [Adventure + Nonfiction] [25] (Original-OR) ORIGINAL_25recommendation.csv -> 2771 books -> Adventure + Nonfiction Original-OR: avg/user=8.31, unique=851
# [Adventure + Nonfiction] [35] (Original-G1) ORIGINAL_35recommendation.csv -> 3366 books -> Adventure + Nonfiction Original-G1: avg/user=6.99, unique=663
# [Adventure + Nonfiction] [35] (Original-G2) ORIGINAL_35recommendation.csv -> 3366 books -> Adventure + Nonfiction Original-G2: avg/user=4.71, unique=375
# [Adventure + Nonfiction] [35] (Original-AND) ORIGINAL_35recommendation.csv -> 3366 books -> Adventure + Nonfiction Original-AND: avg/user=0.08, unique=18
# [Adventure + Nonfiction] [35] (Original-OR) ORIGINAL_35recommendation.csv -> 3366 books -> Adventure + Nonfiction Original-OR: avg/user=11.61, unique=1020
# [Adventure + Nonfiction] [15] (G1) forpair_Adventure__Nonfiction_2u_pos5_neg1_OR_15recommendation.csv -> 2021 books -> Adventure + Nonfiction G1: avg/user=2.92, unique=404
# [Adventure + Nonfiction] [15] (G2) forpair_Adventure__Nonfiction_2u_pos5_neg1_OR_15recommendation.csv -> 2021 books -> Adventure + Nonfiction G2: avg/user=1.98, unique=237
# [Adventure + Nonfiction] [15] (AND) forpair_Adventure__Nonfiction_2u_pos5_neg1_OR_15recommendation.csv -> 2021 books -> Adventure + Nonfiction AND: avg/user=0.04, unique=13
# [Adventure + Nonfiction] [15] (OR) forpair_Adventure__Nonfiction_2u_pos5_neg1_OR_15recommendation.csv -> 2021 books -> Adventure + Nonfiction OR: avg/user=4.86, unique=628
# [Adventure + Nonfiction] [15] (G1) forpair_Adventure__Nonfiction_6u_pos5_neg1_OR_15recommendation.csv -> 1918 books -> Adventure + Nonfiction G1: avg/user=3.51, unique=410
# [Adventure + Nonfiction] [15] (G2) forpair_Adventure__Nonfiction_6u_pos5_neg1_OR_15recommendation.csv -> 1918 books -> Adventure + Nonfiction G2: avg/user=2.24, unique=238
# [Adventure + Nonfiction] [15] (AND) forpair_Adventure__Nonfiction_6u_pos5_neg1_OR_15recommendation.csv -> 1918 books -> Adventure + Nonfiction AND: avg/user=0.04, unique=11
# [Adventure + Nonfiction] [15] (OR) forpair_Adventure__Nonfiction_6u_pos5_neg1_OR_15recommendation.csv -> 1918 books -> Adventure + Nonfiction OR: avg/user=5.71, unique=637
# [Adventure + Nonfiction] [15] (G1) forpair_Adventure__Nonfiction_200u_pos5_neg1_OR_15recommendation.csv -> 2093 books -> Adventure + Nonfiction G1: avg/user=3.28, unique=481
# [Adventure + Nonfiction] [15] (G2) forpair_Adventure__Nonfiction_200u_pos5_neg1_OR_15recommendation.csv -> 2093 books -> Adventure + Nonfiction G2: avg/user=1.95, unique=269
# [Adventure + Nonfiction] [15] (AND) forpair_Adventure__Nonfiction_200u_pos5_neg1_OR_15recommendation.csv -> 2093 books -> Adventure + Nonfiction AND: avg/user=0.05, unique=9
# [Adventure + Nonfiction] [15] (OR) forpair_Adventure__Nonfiction_200u_pos5_neg1_OR_15recommendation.csv -> 2093 books -> Adventure + Nonfiction OR: avg/user=5.18, unique=741
# [Adventure + Nonfiction] [25] (G1) forpair_Adventure__Nonfiction_2u_pos5_neg1_OR_25recommendation.csv -> 2729 books -> Adventure + Nonfiction G1: avg/user=5.19, unique=560
# [Adventure + Nonfiction] [25] (G2) forpair_Adventure__Nonfiction_2u_pos5_neg1_OR_25recommendation.csv -> 2729 books -> Adventure + Nonfiction G2: avg/user=3.15, unique=317
# [Adventure + Nonfiction] [25] (AND) forpair_Adventure__Nonfiction_2u_pos5_neg1_OR_25recommendation.csv -> 2729 books -> Adventure + Nonfiction AND: avg/user=0.08, unique=18
# [Adventure + Nonfiction] [25] (OR) forpair_Adventure__Nonfiction_2u_pos5_neg1_OR_25recommendation.csv -> 2729 books -> Adventure + Nonfiction OR: avg/user=8.25, unique=859
