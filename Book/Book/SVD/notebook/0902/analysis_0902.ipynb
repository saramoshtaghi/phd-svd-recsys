# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #0910 ##it works

# %%
#!/usr/bin/env python3
# g1_user_summary_and_reports_final_fix.py
#
# End-to-end:
#  1) Build per-book ORIGINAL mean ratings + per-book genres from df_final_with_genres.csv
#  2) For injected SVD files: f_<Genre>_<n>_..._<K>recommendation.csv
#       • per-user CSV under: <OUT_DIR>/<genre_slug>/<file>__G1_user_summary.csv
#       • collect genre-level stats keyed by (Genre, K, n)
#  3) For ORIGINAL files: ORIGINAL_<K>recommendation.csv (NOTE: only varies by K, no n)
#       • for EACH Genre, per-user CSV under: <OUT_DIR>/original/<genre_slug>/ORIGINAL_<K>recommendation__<genre_slug>__G1_user_summary.csv
#       • collect baseline stats keyed by (Genre, K)
#  4) Write per-genre TXT:
#       • general.txt  -> table: Genre,n,K,avg_count,avg_estimation_rating,avg_original_rating
#                         (one ORIGINAL line per K, plus one line per injected run)
#       • report.txt   -> human-readable: for each Top K, show ORIGINAL once (no n), then runs n=25/50
#
# A book matches target genre if target appears in genre_g1 OR genre_g2.
# Users with 0 matches: count=0; averages NaN (skipped in higher-level means).
# Robust to missing genre columns and book_id dtype mismatches.

import os
import re
from pathlib import Path
import pandas as pd
from collections import defaultdict

# ======== CONFIG (update if needed) ========
ORIGINAL_CSV = Path("/home/moshtasa/Research/phd-svd-recsys/SVD/Book/data/df_final_with_genres.csv")
RECS_DIR     = Path("/home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/0902/SVD")
OUT_DIR      = Path("/home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/0902/result/G1_user_summary")
OUT_DIR.mkdir(parents=True, exist_ok=True)

GENRE_LIST = [
    "Adult", "Adventure", "Children's", "Classics", "Drama", "Fantasy",
    "Historical", "Horror", "Mystery", "Nonfiction", "Romance",
    "Science Fiction", "Thriller",
]

# ======== HELPERS ========
def parse_target_genre(fname: str) -> str:
    base = os.path.basename(fname)
    # enhanced_<Genre>_<n>_... or f_<Genre>_<n>_...
    m = (re.match(r"(?:enhanced|f)_([^_]+)_\d+_.*recommendation\.csv", base)
         or re.match(r"(?:enhanced|f)_([^_]+)_.*recommendation\.csv", base))
    token = m.group(1) if m else "Unknown"
    return {"Children_s": "Children's", "Science_Fiction": "Science Fiction"}.get(
        token, token.replace("_", " ")
    )

def parse_run_from_filename(name: str) -> int:
    base = os.path.basename(name)
    m = re.match(r"(?:enhanced|f)_[^_]+_(\d+)_", base)
    return int(m.group(1)) if m else -1

def parse_k_from_filename(name: str) -> int:
    m = re.search(r"_(15|25|35)recommendation\.csv$", os.path.basename(name))
    return int(m.group(1)) if m else -1

def slugify(s: str) -> str:
    return re.sub(r"[^A-Za-z0-9]+", "_", s).strip("_").lower()

def genre_folder(genre: str, *, original: bool=False) -> Path:
    base = OUT_DIR / ("original" if original else "")
    gdir = base / slugify(genre)
    gdir.mkdir(parents=True, exist_ok=True)
    return gdir

def summary_csv_path(rec_path: Path, gdir: Path, *, original: bool, genre: str) -> Path:
    if original:
        k = parse_k_from_filename(rec_path.name)
        return gdir / f"ORIGINAL_{k}recommendation__{slugify(genre)}__G1_user_summary.csv"
    return gdir / f"{rec_path.stem}__G1_user_summary.csv"

def fmt(x):
    return "" if pd.isna(x) else f"{float(x):.6f}"

def split_genre_cols(df: pd.DataFrame) -> pd.DataFrame:
    def split_one(gen):
        if pd.isna(gen) or not str(gen).strip():
            return ("Unknown", "", "Unknown")
        parts = [p.strip() for p in str(gen).split(",") if p.strip()]
        g1 = parts[0] if len(parts) >= 1 else "Unknown"
        g2 = parts[1] if len(parts) >= 2 else ""
        return (g1, g2, ", ".join(parts) if parts else "Unknown")
    g = (df[["book_id","genres"]]
         .dropna(subset=["book_id"])
         .drop_duplicates("book_id", keep="first")
         .copy())
    g[["genre_g1","genre_g2","genres_all"]] = pd.DataFrame(g["genres"].apply(split_one).tolist(), index=g.index)
    return g.drop(columns=["genres"])

def ensure_genres_on_rec(df: pd.DataFrame, book_genres: pd.DataFrame) -> pd.DataFrame:
    # dtype-safe join on book_id
    if "book_id" in df.columns and "book_id" in book_genres.columns:
        try:
            df = df.copy()
            df["book_id"] = pd.to_numeric(df["book_id"], errors="coerce").astype("Int64")
            bg = book_genres.copy()
            bg["book_id"] = pd.to_numeric(bg["book_id"], errors="coerce").astype("Int64")
        except Exception:
            bg = book_genres.copy()
    else:
        bg = book_genres.copy()

    if not {"genre_g1","genre_g2"}.issubset(df.columns):
        df = df.merge(bg, on="book_id", how="left")

    for col in ["genre_g1","genre_g2"]:
        if col not in df.columns:
            df[col] = pd.NA
    return df

def compute_user_summary(rec_df: pd.DataFrame, target_genre: str, count_col: str,
                         book_means: pd.DataFrame, book_genres: pd.DataFrame) -> pd.DataFrame:
    rec_df = ensure_genres_on_rec(rec_df, book_genres)
    users = pd.DataFrame({"user_id": rec_df["user_id"].drop_duplicates().sort_values().values})

    gmask = (rec_df["genre_g1"] == target_genre) | (rec_df["genre_g2"] == target_genre)
    rec_g1 = rec_df[gmask].copy()

    cnt = (rec_g1.groupby("user_id", as_index=False)["book_id"].count()
           .rename(columns={"book_id": count_col}))

    if "est_score" not in rec_g1.columns:
        rec_g1["est_score"] = pd.NA
    est_mean = (rec_g1.groupby("user_id", as_index=False)["est_score"].mean()
                .rename(columns={"est_score":"estimation_rating_average"}))

    rec_g1 = rec_g1.merge(book_means, on="book_id", how="left")
    orig_mean = (rec_g1.groupby("user_id", as_index=False)["original_per_book_avg"].mean()
                 .rename(columns={"original_per_book_avg":"rating_average"}))

    out = users.merge(cnt, on="user_id", how="left")
    out[count_col] = out[count_col].fillna(0).astype("int64")
    out = out.merge(est_mean, on="user_id", how="left").merge(orig_mean, on="user_id", how="left")
    return out

def append_table_line(general_path: Path, header: str, line: str):
    write_header = not general_path.exists() or os.path.getsize(general_path) == 0
    with open(general_path, "a", encoding="utf-8") as f:
        if write_header:
            f.write(header)
        f.write(line)

# ======== LOAD ORIGINAL RATING DATA ========
print("Loading original ratings …")
orig = pd.read_csv(ORIGINAL_CSV, usecols=["book_id","rating","user_id","genres"])
book_means  = (orig.groupby("book_id", as_index=False)["rating"].mean()
               .rename(columns={"rating":"original_per_book_avg"}))
book_genres = split_genre_cols(orig)  # book_id, genre_g1, genre_g2, genres_all
del orig

# ======== ACCUMULATORS ========
# injected_stats[genre][K][n] = (avg_count, avg_est, avg_orig)
# original_stats[genre][K]    = (avg_count, avg_est, avg_orig)
injected_stats = defaultdict(lambda: defaultdict(dict))
original_stats = defaultdict(dict)

# ======== PROCESS INJECTED f_* FILES ========
for rec_path in sorted(RECS_DIR.glob("enhanced_*recommendation.csv")):
    genre = parse_target_genre(rec_path.name)
    k     = parse_k_from_filename(rec_path.name)
    n     = parse_run_from_filename(rec_path.name)
    gdir  = genre_folder(genre, original=False)

    rec = pd.read_csv(rec_path)
    need = {"user_id","book_id","rank"}
    if not need.issubset(rec.columns):
        raise ValueError(f"{rec_path.name} must have {need}")

    count_col = f"number_of_books_suggested_in_{slugify(genre)}"
    out = compute_user_summary(rec, genre, count_col, book_means, book_genres)
    out.to_csv(summary_csv_path(rec_path, gdir, original=False, genre=genre), index=False)

    avg_count = float(out[count_col].astype("float64").mean())
    avg_est   = float(out["estimation_rating_average"].mean(skipna=True))
    avg_orig  = float(out["rating_average"].mean(skipna=True))
    injected_stats[genre][k][n] = (avg_count, avg_est, avg_orig)

# ======== PROCESS ORIGINAL_* FILES (ONLY K VARIES) ========
for rec_path in sorted(RECS_DIR.glob("ORIGINAL_*recommendation.csv")):
    k = parse_k_from_filename(rec_path.name)
    recb = pd.read_csv(rec_path)
    need = {"user_id","book_id","rank"}
    if not need.issubset(recb.columns):
        raise ValueError(f"{rec_path.name} must have {need}")
    recb = ensure_genres_on_rec(recb, book_genres)

    for genre in GENRE_LIST:
        gdir = genre_folder(genre, original=True)
        count_col = f"number_of_books_suggested_in_{slugify(genre)}"
        out = compute_user_summary(recb, genre, count_col, book_means, book_genres)
        out.to_csv(summary_csv_path(rec_path, gdir, original=True, genre=genre), index=False)

        avg_count = float(out[count_col].astype("float64").mean())
        avg_est   = float(out["estimation_rating_average"].mean(skipna=True))
        avg_orig  = float(out["rating_average"].mean(skipna=True))
        original_stats[genre][k] = (avg_count, avg_est, avg_orig)

# ======== WRITE TXT OUTPUTS PER GENRE ========
for genre in GENRE_LIST:
    gdir_inj = genre_folder(genre, original=False)
    general_path = gdir_inj / "general.txt"
    report_path  = gdir_inj / "report.txt"

    # --- general.txt: table (overwrite each run to avoid duplicates) ---
    if general_path.exists():
        general_path.unlink()
    header = "Genre,n,K,avg_count,avg_estimation_rating,avg_original_rating\n"

    Ks = sorted(set(list(injected_stats[genre].keys()) + list(original_stats[genre].keys())))
    for k in Ks:
        # ORIGINAL: one line per K with n="ORIGINAL"
        oc, oe, oo = original_stats[genre].get(k, (float('nan'), float('nan'), float('nan')))
        append_table_line(general_path, header, f"{genre},ORIGINAL,{k},{fmt(oc)},{fmt(oe)},{fmt(oo)}\n")
        # Injected runs for this K
        for n, (ic, ie, io) in sorted(injected_stats[genre].get(k, {}).items()):
            append_table_line(general_path, header, f"{genre},{n},{k},{fmt(ic)},{fmt(ie)},{fmt(io)}\n")

    # --- report.txt: human-readable (ORIGINAL once per K, then runs) ---
    lines = []
    lines.append(f"# Report for {genre}\n\n")
    for k in Ks:
        lines.append(f"Top {k}:\n")
        oc, oe, oo = original_stats[genre].get(k, (float('nan'), float('nan'), float('nan')))
        lines.append(f"- original_{k}:          count={fmt(oc)}, est={fmt(oe)}, orig={fmt(oo)}\n")
        runs = sorted(injected_stats[genre].get(k, {}).keys())
        for n in runs:
            ic, ie, io = injected_stats[genre][k][n]
            lines.append(f"- {slugify(genre)}_{k}_{n}:  count={fmt(ic)}, est={fmt(ie)}, orig={fmt(io)}\n")
        lines.append("\n")
    with open(report_path, "w", encoding="utf-8") as f:
        f.writelines(lines)

print("\nDone.")
print(f"Outputs under: {OUT_DIR}")
print("Injected per-genre CSVs:   result/<genre>/...__G1_user_summary.csv")
print("Original  per-genre CSVs:  result/original/<genre>/ORIGINAL_*__G1_user_summary.csv")
print("Per-genre TXT summaries:   result/<genre>/general.txt and report.txt")
# Out:
# Loading original ratings …
#
# Done.
# Outputs under: /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/0902/result/G1_user_summary
# Injected per-genre CSVs:   result/<genre>/...__G1_user_summary.csv
# Original  per-genre CSVs:  result/original/<genre>/ORIGINAL_*__G1_user_summary.csv
# Per-genre TXT summaries:   result/<genre>/general.txt and report.txt

# %% [markdown]
# ##THRESHOLDS

# %%
#!/usr/bin/env python3
# count_est_over_thresholds.py
#
# Usage (no args uses your defaults):
#   python -u count_est_over_thresholds.py
# Or pass files/dirs:
#   python -u count_est_over_thresholds.py /path/to/0902/SVD /path/to/0909/SVD

import sys, os, glob
import pandas as pd

# --- defaults (edit if your folders differ) ---
DIR_0902 = "/home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/0902/SVD"
DIR_0909 = "/home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/0909/SVD"

THRESHOLDS = [5.0, 7.0, 8.0, 9.0, 10.0] # counts for >5 and >7
CHUNK = 500_000           # adjust if you want

def collect_paths(arg):
    if os.path.isdir(arg):
        return sorted(glob.glob(os.path.join(arg, "*recommendation.csv")))
    elif os.path.isfile(arg):
        return [arg]
    else:
        return []

def normalize_inputs(argv):
    # ignore ipython flags like --f=...
    args = [a for a in argv if not a.startswith("-")]
    paths = []
    for a in args:
        paths += collect_paths(a)
    if not paths:
        # fallback to defaults: both folders
        paths = collect_paths(DIR_0902) + collect_paths(DIR_0909)
    return paths

def scan_file(path):
    total = 0
    over = {thr: 0 for thr in THRESHOLDS}
    min_est, max_est, sum_est = float("inf"), float("-inf"), 0.0
    for chunk in pd.read_csv(path, usecols=["est_score"], chunksize=CHUNK):
        s = pd.to_numeric(chunk["est_score"], errors="coerce")
        total += s.size
        sum_est += s.sum(skipna=True)
        if s.size:
            min_est = min(min_est, float(s.min()))
            max_est = max(max_est, float(s.max()))
        for thr in THRESHOLDS:
            over[thr] += int((s > thr).sum())
    avg_est = (sum_est / total) if total else float("nan")
    return total, min_est, max_est, avg_est, over

def main():
    paths = normalize_inputs(sys.argv[1:])
    if not paths:
        print("[ERR] No recommendation CSVs found.")
        return

    # group by folder for summaries
    by_dir = {}
    print(f"[INFO] Scanning {len(paths)} file(s)...")
    for p in paths:
        d = os.path.dirname(p)
        by_dir.setdefault(d, {"files": [], "total": 0, "over": {thr:0 for thr in THRESHOLDS}})
        total, mn, mx, avg, over = scan_file(p)
        by_dir[d]["files"].append((p, total, mn, mx, avg, over))
        by_dir[d]["total"] += total
        for thr in THRESHOLDS:
            by_dir[d]["over"][thr] += over[thr]

    # per-file report
    for d, info in by_dir.items():
        print("\n" + "="*100)
        print(f"[DIR] {d}")
        for (p, total, mn, mx, avg, over) in info["files"]:
            base = os.path.basename(p)
            tail = ", ".join([f"> {thr:g}: {over[thr]:,} ({over[thr]/total:.2%})" for thr in THRESHOLDS])
            print(f"{base:60s} | rows={total:,} | min={mn:.4f} max={mx:.4f} avg={avg:.4f} | {tail}")

    # per-directory summary
    print("\n" + "#"*100)
    print("# SUMMARY BY DIRECTORY")
    for d, info in by_dir.items():
        total = info["total"]
        tail = " | ".join([f"> {thr:g}: {info['over'][thr]:,} ({info['over'][thr]/total:.2%})" for thr in THRESHOLDS])
        print(f"{d}\n  files={len(info['files'])}, rows={total:,} | {tail}\n")

if __name__ == "__main__":
    main()
# Out:
# [INFO] Scanning 207 file(s)...
#
# ====================================================================================================
# [DIR] /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/0902/SVD
# ORIGINAL_15recommendation.csv                                | rows=801,360 | min=1.7773 max=25.7982 avg=5.7794 | > 5: 689,016 (85.98%), > 7: 58,331 (7.28%), > 8: 14,750 (1.84%), > 9: 4,644 (0.58%), > 10: 1,641 (0.20%)
# ORIGINAL_25recommendation.csv                                | rows=1,335,600 | min=1.7336 max=25.7982 avg=5.6452 | > 5: 1,092,827 (81.82%), > 7: 71,064 (5.32%), > 8: 17,485 (1.31%), > 9: 5,427 (0.41%), > 10: 1,906 (0.14%)
# ORIGINAL_35recommendation.csv                                | rows=1,869,840 | min=1.6932 max=25.7982 avg=5.5585 | > 5: 1,469,636 (78.60%), > 7: 79,564 (4.26%), > 8: 19,353 (1.04%), > 9: 5,887 (0.31%), > 10: 2,071 (0.11%)
# enhanced_Adult_100_pos5_neg0_sample_15recommendation.csv     | rows=801,360 | min=1.7245 max=24.7811 avg=5.7802 | > 5: 688,012 (85.86%), > 7: 57,612 (7.19%), > 8: 14,650 (1.83%), > 9: 4,669 (0.58%), > 10: 1,811 (0.23%)
# enhanced_Adult_100_pos5_neg0_sample_25recommendation.csv     | rows=1,335,600 | min=1.6602 max=24.7811 avg=5.6545 | > 5: 1,096,013 (82.06%), > 7: 70,835 (5.30%), > 8: 17,638 (1.32%), > 9: 5,559 (0.42%), > 10: 2,125 (0.16%)
# enhanced_Adult_100_pos5_neg0_sample_35recommendation.csv     | rows=1,869,840 | min=1.6334 max=24.7811 avg=5.5705 | > 5: 1,477,411 (79.01%), > 7: 79,911 (4.27%), > 8: 19,637 (1.05%), > 9: 6,151 (0.33%), > 10: 2,337 (0.12%)
# enhanced_Adult_200_pos5_neg0_sample_15recommendation.csv     | rows=801,360 | min=1.8406 max=17.6772 avg=5.7331 | > 5: 677,210 (84.51%), > 7: 52,451 (6.55%), > 8: 13,662 (1.70%), > 9: 4,190 (0.52%), > 10: 1,448 (0.18%)
# enhanced_Adult_200_pos5_neg0_sample_25recommendation.csv     | rows=1,335,600 | min=1.7689 max=17.6772 avg=5.6109 | > 5: 1,075,438 (80.52%), > 7: 64,659 (4.84%), > 8: 16,297 (1.22%), > 9: 4,908 (0.37%), > 10: 1,642 (0.12%)
# enhanced_Adult_200_pos5_neg0_sample_35recommendation.csv     | rows=1,869,840 | min=1.7125 max=17.6772 avg=5.5303 | > 5: 1,447,518 (77.41%), > 7: 73,060 (3.91%), > 8: 17,931 (0.96%), > 9: 5,321 (0.28%), > 10: 1,785 (0.10%)
# enhanced_Adult_25_pos5_neg0_sample_15recommendation.csv      | rows=801,360 | min=1.7399 max=18.5162 avg=5.7217 | > 5: 679,931 (84.85%), > 7: 49,122 (6.13%), > 8: 12,274 (1.53%), > 9: 3,757 (0.47%), > 10: 1,470 (0.18%)
# enhanced_Adult_25_pos5_neg0_sample_25recommendation.csv      | rows=1,335,600 | min=1.7136 max=18.5162 avg=5.6053 | > 5: 1,081,500 (80.97%), > 7: 61,222 (4.58%), > 8: 14,653 (1.10%), > 9: 4,478 (0.34%), > 10: 1,737 (0.13%)
# enhanced_Adult_25_pos5_neg0_sample_35recommendation.csv      | rows=1,869,840 | min=1.6756 max=18.5162 avg=5.5278 | > 5: 1,457,169 (77.93%), > 7: 69,466 (3.72%), > 8: 16,281 (0.87%), > 9: 4,986 (0.27%), > 10: 1,899 (0.10%)
# enhanced_Adult_50_pos5_neg0_sample_15recommendation.csv      | rows=801,360 | min=1.8150 max=24.7709 avg=5.7579 | > 5: 682,549 (85.17%), > 7: 56,448 (7.04%), > 8: 15,357 (1.92%), > 9: 4,895 (0.61%), > 10: 1,731 (0.22%)
# enhanced_Adult_50_pos5_neg0_sample_25recommendation.csv      | rows=1,335,600 | min=1.7412 max=24.7709 avg=5.6333 | > 5: 1,086,068 (81.32%), > 7: 69,694 (5.22%), > 8: 18,284 (1.37%), > 9: 5,696 (0.43%), > 10: 1,981 (0.15%)
# enhanced_Adult_50_pos5_neg0_sample_35recommendation.csv      | rows=1,869,840 | min=1.6847 max=24.7709 avg=5.5510 | > 5: 1,463,113 (78.25%), > 7: 78,833 (4.22%), > 8: 20,279 (1.08%), > 9: 6,174 (0.33%), > 10: 2,171 (0.12%)
# enhanced_Adventure_100_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7431 max=21.5704 avg=5.7571 | > 5: 684,584 (85.43%), > 7: 53,179 (6.64%), > 8: 13,099 (1.63%), > 9: 3,834 (0.48%), > 10: 1,381 (0.17%)
# enhanced_Adventure_100_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.6959 max=21.5704 avg=5.6364 | > 5: 1,089,968 (81.61%), > 7: 65,992 (4.94%), > 8: 15,691 (1.17%), > 9: 4,495 (0.34%), > 10: 1,681 (0.13%)
# enhanced_Adventure_100_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6669 max=21.5704 avg=5.5555 | > 5: 1,469,981 (78.62%), > 7: 74,922 (4.01%), > 8: 17,429 (0.93%), > 9: 4,960 (0.27%), > 10: 1,880 (0.10%)
# enhanced_Adventure_200_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.8527 max=19.2738 avg=5.7340 | > 5: 680,802 (84.96%), > 7: 51,080 (6.37%), > 8: 12,491 (1.56%), > 9: 3,873 (0.48%), > 10: 1,377 (0.17%)
# enhanced_Adventure_200_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7883 max=19.2738 avg=5.6149 | > 5: 1,082,840 (81.08%), > 7: 63,144 (4.73%), > 8: 15,125 (1.13%), > 9: 4,624 (0.35%), > 10: 1,638 (0.12%)
# enhanced_Adventure_200_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.7390 max=19.2738 avg=5.5356 | > 5: 1,457,906 (77.97%), > 7: 71,540 (3.83%), > 8: 16,924 (0.91%), > 9: 5,116 (0.27%), > 10: 1,830 (0.10%)
# enhanced_Adventure_25_pos5_neg0_sample_15recommendation.csv  | rows=801,360 | min=1.7328 max=20.0477 avg=5.7284 | > 5: 679,717 (84.82%), > 7: 50,962 (6.36%), > 8: 13,197 (1.65%), > 9: 4,163 (0.52%), > 10: 1,557 (0.19%)
# enhanced_Adventure_25_pos5_neg0_sample_25recommendation.csv  | rows=1,335,600 | min=1.6918 max=20.0477 avg=5.6077 | > 5: 1,079,994 (80.86%), > 7: 62,694 (4.69%), > 8: 15,665 (1.17%), > 9: 4,894 (0.37%), > 10: 1,838 (0.14%)
# enhanced_Adventure_25_pos5_neg0_sample_35recommendation.csv  | rows=1,869,840 | min=1.6526 max=20.0477 avg=5.5285 | > 5: 1,454,327 (77.78%), > 7: 70,872 (3.79%), > 8: 17,319 (0.93%), > 9: 5,394 (0.29%), > 10: 2,006 (0.11%)
# enhanced_Adventure_50_pos5_neg0_sample_15recommendation.csv  | rows=801,360 | min=1.8107 max=24.4290 avg=5.7616 | > 5: 683,092 (85.24%), > 7: 57,007 (7.11%), > 8: 15,101 (1.88%), > 9: 4,753 (0.59%), > 10: 1,676 (0.21%)
# enhanced_Adventure_50_pos5_neg0_sample_25recommendation.csv  | rows=1,335,600 | min=1.7342 max=24.4290 avg=5.6346 | > 5: 1,085,224 (81.25%), > 7: 70,039 (5.24%), > 8: 17,950 (1.34%), > 9: 5,529 (0.41%), > 10: 1,928 (0.14%)
# enhanced_Adventure_50_pos5_neg0_sample_35recommendation.csv  | rows=1,869,840 | min=1.6778 max=24.4290 avg=5.5510 | > 5: 1,460,502 (78.11%), > 7: 79,046 (4.23%), > 8: 19,823 (1.06%), > 9: 5,990 (0.32%), > 10: 2,119 (0.11%)
# enhanced_Children_s_100_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7877 max=21.2827 avg=5.7586 | > 5: 687,864 (85.84%), > 7: 53,216 (6.64%), > 8: 13,228 (1.65%), > 9: 3,955 (0.49%), > 10: 1,413 (0.18%)
# enhanced_Children_s_100_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7155 max=21.2827 avg=5.6346 | > 5: 1,093,513 (81.87%), > 7: 65,559 (4.91%), > 8: 15,769 (1.18%), > 9: 4,676 (0.35%), > 10: 1,673 (0.13%)
# enhanced_Children_s_100_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6623 max=21.2827 avg=5.5523 | > 5: 1,471,756 (78.71%), > 7: 74,152 (3.97%), > 8: 17,544 (0.94%), > 9: 5,163 (0.28%), > 10: 1,828 (0.10%)
# enhanced_Children_s_200_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.8014 max=18.2999 avg=5.7549 | > 5: 687,564 (85.80%), > 7: 53,738 (6.71%), > 8: 13,582 (1.69%), > 9: 4,249 (0.53%), > 10: 1,479 (0.18%)
# enhanced_Children_s_200_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7614 max=18.2999 avg=5.6245 | > 5: 1,090,449 (81.64%), > 7: 65,216 (4.88%), > 8: 15,930 (1.19%), > 9: 4,901 (0.37%), > 10: 1,686 (0.13%)
# enhanced_Children_s_200_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6917 max=18.2999 avg=5.5385 | > 5: 1,463,676 (78.28%), > 7: 72,942 (3.90%), > 8: 17,431 (0.93%), > 9: 5,304 (0.28%), > 10: 1,793 (0.10%)
# enhanced_Children_s_25_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7518 max=20.1992 avg=5.7178 | > 5: 677,771 (84.58%), > 7: 49,332 (6.16%), > 8: 12,604 (1.57%), > 9: 3,877 (0.48%), > 10: 1,396 (0.17%)
# enhanced_Children_s_25_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7051 max=20.1992 avg=5.5986 | > 5: 1,077,245 (80.66%), > 7: 60,535 (4.53%), > 8: 14,883 (1.11%), > 9: 4,492 (0.34%), > 10: 1,590 (0.12%)
# enhanced_Children_s_25_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6753 max=20.1992 avg=5.5202 | > 5: 1,450,288 (77.56%), > 7: 68,266 (3.65%), > 8: 16,349 (0.87%), > 9: 4,910 (0.26%), > 10: 1,739 (0.09%)
# enhanced_Children_s_50_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7449 max=25.2025 avg=5.7319 | > 5: 680,439 (84.91%), > 7: 50,980 (6.36%), > 8: 13,138 (1.64%), > 9: 4,023 (0.50%), > 10: 1,404 (0.18%)
# enhanced_Children_s_50_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7043 max=25.2025 avg=5.6065 | > 5: 1,078,560 (80.75%), > 7: 62,145 (4.65%), > 8: 15,430 (1.16%), > 9: 4,596 (0.34%), > 10: 1,585 (0.12%)
# enhanced_Children_s_50_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6669 max=25.2025 avg=5.5243 | > 5: 1,449,818 (77.54%), > 7: 69,849 (3.74%), > 8: 16,942 (0.91%), > 9: 4,925 (0.26%), > 10: 1,706 (0.09%)
# enhanced_Classics_100_pos5_neg0_sample_15recommendation.csv  | rows=801,360 | min=1.7926 max=20.9843 avg=5.7459 | > 5: 683,036 (85.23%), > 7: 52,371 (6.54%), > 8: 12,908 (1.61%), > 9: 3,826 (0.48%), > 10: 1,265 (0.16%)
# enhanced_Classics_100_pos5_neg0_sample_25recommendation.csv  | rows=1,335,600 | min=1.7362 max=20.9843 avg=5.6246 | > 5: 1,085,866 (81.30%), > 7: 64,681 (4.84%), > 8: 15,370 (1.15%), > 9: 4,528 (0.34%), > 10: 1,505 (0.11%)
# enhanced_Classics_100_pos5_neg0_sample_35recommendation.csv  | rows=1,869,840 | min=1.6866 max=20.9843 avg=5.5433 | > 5: 1,461,469 (78.16%), > 7: 72,890 (3.90%), > 8: 17,014 (0.91%), > 9: 4,971 (0.27%), > 10: 1,669 (0.09%)
# enhanced_Classics_200_pos5_neg0_sample_15recommendation.csv  | rows=801,360 | min=1.7655 max=18.3850 avg=5.7103 | > 5: 672,938 (83.97%), > 7: 49,258 (6.15%), > 8: 12,802 (1.60%), > 9: 4,001 (0.50%), > 10: 1,400 (0.17%)
# enhanced_Classics_200_pos5_neg0_sample_25recommendation.csv  | rows=1,335,600 | min=1.6982 max=18.3850 avg=5.5942 | > 5: 1,069,861 (80.10%), > 7: 61,325 (4.59%), > 8: 15,375 (1.15%), > 9: 4,744 (0.36%), > 10: 1,635 (0.12%)
# enhanced_Classics_200_pos5_neg0_sample_35recommendation.csv  | rows=1,869,840 | min=1.6597 max=18.3850 avg=5.5159 | > 5: 1,439,352 (76.98%), > 7: 69,530 (3.72%), > 8: 17,053 (0.91%), > 9: 5,216 (0.28%), > 10: 1,806 (0.10%)
# enhanced_Classics_25_pos5_neg0_sample_15recommendation.csv   | rows=801,360 | min=1.7776 max=19.2917 avg=5.7151 | > 5: 676,031 (84.36%), > 7: 49,371 (6.16%), > 8: 12,862 (1.61%), > 9: 4,142 (0.52%), > 10: 1,593 (0.20%)
# enhanced_Classics_25_pos5_neg0_sample_25recommendation.csv   | rows=1,335,600 | min=1.7138 max=19.2917 avg=5.5967 | > 5: 1,074,396 (80.44%), > 7: 60,885 (4.56%), > 8: 15,384 (1.15%), > 9: 4,901 (0.37%), > 10: 1,846 (0.14%)
# enhanced_Classics_25_pos5_neg0_sample_35recommendation.csv   | rows=1,869,840 | min=1.6811 max=19.2917 avg=5.5186 | > 5: 1,446,738 (77.37%), > 7: 69,041 (3.69%), > 8: 17,098 (0.91%), > 9: 5,429 (0.29%), > 10: 2,037 (0.11%)
# enhanced_Classics_50_pos5_neg0_sample_15recommendation.csv   | rows=801,360 | min=1.8072 max=27.6824 avg=5.7178 | > 5: 675,010 (84.23%), > 7: 50,463 (6.30%), > 8: 12,769 (1.59%), > 9: 3,878 (0.48%), > 10: 1,383 (0.17%)
# enhanced_Classics_50_pos5_neg0_sample_25recommendation.csv   | rows=1,335,600 | min=1.7457 max=27.6824 avg=5.5992 | > 5: 1,071,354 (80.22%), > 7: 62,631 (4.69%), > 8: 15,203 (1.14%), > 9: 4,636 (0.35%), > 10: 1,651 (0.12%)
# enhanced_Classics_50_pos5_neg0_sample_35recommendation.csv   | rows=1,869,840 | min=1.6984 max=27.6824 avg=5.5204 | > 5: 1,441,915 (77.11%), > 7: 70,957 (3.79%), > 8: 16,907 (0.90%), > 9: 5,103 (0.27%), > 10: 1,834 (0.10%)
# enhanced_Drama_100_pos5_neg0_sample_15recommendation.csv     | rows=801,360 | min=1.7475 max=26.2000 avg=5.7455 | > 5: 680,744 (84.95%), > 7: 53,228 (6.64%), > 8: 13,038 (1.63%), > 9: 3,946 (0.49%), > 10: 1,367 (0.17%)
# enhanced_Drama_100_pos5_neg0_sample_25recommendation.csv     | rows=1,335,600 | min=1.7112 max=26.2000 avg=5.6228 | > 5: 1,082,422 (81.04%), > 7: 65,113 (4.88%), > 8: 15,505 (1.16%), > 9: 4,667 (0.35%), > 10: 1,599 (0.12%)
# enhanced_Drama_100_pos5_neg0_sample_35recommendation.csv     | rows=1,869,840 | min=1.6561 max=26.2000 avg=5.5413 | > 5: 1,457,567 (77.95%), > 7: 73,278 (3.92%), > 8: 17,104 (0.91%), > 9: 5,120 (0.27%), > 10: 1,769 (0.09%)
# enhanced_Drama_200_pos5_neg0_sample_15recommendation.csv     | rows=801,360 | min=1.7907 max=19.0924 avg=5.7183 | > 5: 674,963 (84.23%), > 7: 50,137 (6.26%), > 8: 12,898 (1.61%), > 9: 3,937 (0.49%), > 10: 1,496 (0.19%)
# enhanced_Drama_200_pos5_neg0_sample_25recommendation.csv     | rows=1,335,600 | min=1.7244 max=19.0924 avg=5.6005 | > 5: 1,072,742 (80.32%), > 7: 61,942 (4.64%), > 8: 15,364 (1.15%), > 9: 4,668 (0.35%), > 10: 1,813 (0.14%)
# enhanced_Drama_200_pos5_neg0_sample_35recommendation.csv     | rows=1,869,840 | min=1.7016 max=19.0924 avg=5.5223 | > 5: 1,443,689 (77.21%), > 7: 70,133 (3.75%), > 8: 16,988 (0.91%), > 9: 5,184 (0.28%), > 10: 2,004 (0.11%)
# enhanced_Drama_25_pos5_neg0_sample_15recommendation.csv      | rows=801,360 | min=1.8146 max=18.1043 avg=5.7370 | > 5: 683,947 (85.35%), > 7: 51,143 (6.38%), > 8: 12,904 (1.61%), > 9: 4,050 (0.51%), > 10: 1,501 (0.19%)
# enhanced_Drama_25_pos5_neg0_sample_25recommendation.csv      | rows=1,335,600 | min=1.7396 max=18.1043 avg=5.6160 | > 5: 1,088,025 (81.46%), > 7: 63,085 (4.72%), > 8: 15,408 (1.15%), > 9: 4,767 (0.36%), > 10: 1,738 (0.13%)
# enhanced_Drama_25_pos5_neg0_sample_35recommendation.csv      | rows=1,869,840 | min=1.6783 max=18.1043 avg=5.5362 | > 5: 1,465,619 (78.38%), > 7: 71,280 (3.81%), > 8: 17,098 (0.91%), > 9: 5,282 (0.28%), > 10: 1,895 (0.10%)
# enhanced_Drama_50_pos5_neg0_sample_15recommendation.csv      | rows=801,360 | min=1.7938 max=21.4961 avg=5.7403 | > 5: 676,242 (84.39%), > 7: 55,620 (6.94%), > 8: 15,079 (1.88%), > 9: 4,657 (0.58%), > 10: 1,686 (0.21%)
# enhanced_Drama_50_pos5_neg0_sample_25recommendation.csv      | rows=1,335,600 | min=1.7204 max=21.4961 avg=5.6165 | > 5: 1,075,259 (80.51%), > 7: 68,525 (5.13%), > 8: 17,839 (1.34%), > 9: 5,365 (0.40%), > 10: 1,898 (0.14%)
# enhanced_Drama_50_pos5_neg0_sample_35recommendation.csv      | rows=1,869,840 | min=1.6831 max=21.4961 avg=5.5356 | > 5: 1,448,583 (77.47%), > 7: 77,461 (4.14%), > 8: 19,666 (1.05%), > 9: 5,793 (0.31%), > 10: 2,066 (0.11%)
# enhanced_Fantasy_100_pos5_neg0_sample_15recommendation.csv   | rows=801,360 | min=1.7599 max=21.9261 avg=5.6672 | > 5: 663,658 (82.82%), > 7: 43,244 (5.40%), > 8: 10,280 (1.28%), > 9: 3,120 (0.39%), > 10: 1,163 (0.15%)
# enhanced_Fantasy_100_pos5_neg0_sample_25recommendation.csv   | rows=1,335,600 | min=1.7066 max=21.9261 avg=5.5522 | > 5: 1,051,546 (78.73%), > 7: 52,877 (3.96%), > 8: 12,225 (0.92%), > 9: 3,673 (0.28%), > 10: 1,389 (0.10%)
# enhanced_Fantasy_100_pos5_neg0_sample_35recommendation.csv   | rows=1,869,840 | min=1.6820 max=21.9261 avg=5.4761 | > 5: 1,412,249 (75.53%), > 7: 59,446 (3.18%), > 8: 13,586 (0.73%), > 9: 4,082 (0.22%), > 10: 1,549 (0.08%)
# enhanced_Fantasy_200_pos5_neg0_sample_15recommendation.csv   | rows=801,360 | min=1.6993 max=17.2666 avg=5.5855 | > 5: 645,670 (80.57%), > 7: 33,381 (4.17%), > 8: 7,874 (0.98%), > 9: 2,324 (0.29%), > 10: 770 (0.10%)
# enhanced_Fantasy_200_pos5_neg0_sample_25recommendation.csv   | rows=1,335,600 | min=1.6504 max=17.2666 avg=5.4827 | > 5: 1,019,591 (76.34%), > 7: 41,382 (3.10%), > 8: 9,555 (0.72%), > 9: 2,792 (0.21%), > 10: 941 (0.07%)
# enhanced_Fantasy_200_pos5_neg0_sample_35recommendation.csv   | rows=1,869,840 | min=1.6268 max=17.2666 avg=5.4131 | > 5: 1,366,017 (73.06%), > 7: 47,017 (2.51%), > 8: 10,642 (0.57%), > 9: 3,091 (0.17%), > 10: 1,028 (0.05%)
# enhanced_Fantasy_25_pos5_neg0_sample_15recommendation.csv    | rows=801,360 | min=1.7253 max=25.8661 avg=5.6709 | > 5: 665,945 (83.10%), > 7: 44,348 (5.53%), > 8: 11,194 (1.40%), > 9: 3,350 (0.42%), > 10: 1,205 (0.15%)
# enhanced_Fantasy_25_pos5_neg0_sample_25recommendation.csv    | rows=1,335,600 | min=1.6758 max=25.8661 avg=5.5546 | > 5: 1,055,037 (78.99%), > 7: 54,287 (4.06%), > 8: 13,284 (0.99%), > 9: 3,917 (0.29%), > 10: 1,394 (0.10%)
# enhanced_Fantasy_25_pos5_neg0_sample_35recommendation.csv    | rows=1,869,840 | min=1.6345 max=25.8661 avg=5.4782 | > 5: 1,417,004 (75.78%), > 7: 61,104 (3.27%), > 8: 14,707 (0.79%), > 9: 4,298 (0.23%), > 10: 1,519 (0.08%)
# enhanced_Fantasy_50_pos5_neg0_sample_15recommendation.csv    | rows=801,360 | min=1.7678 max=23.5811 avg=5.6753 | > 5: 666,710 (83.20%), > 7: 45,007 (5.62%), > 8: 11,658 (1.45%), > 9: 3,627 (0.45%), > 10: 1,277 (0.16%)
# enhanced_Fantasy_50_pos5_neg0_sample_25recommendation.csv    | rows=1,335,600 | min=1.7081 max=23.5811 avg=5.5578 | > 5: 1,055,944 (79.06%), > 7: 54,985 (4.12%), > 8: 13,748 (1.03%), > 9: 4,181 (0.31%), > 10: 1,450 (0.11%)
# enhanced_Fantasy_50_pos5_neg0_sample_35recommendation.csv    | rows=1,869,840 | min=1.6891 max=23.5811 avg=5.4805 | > 5: 1,418,372 (75.86%), > 7: 61,839 (3.31%), > 8: 15,148 (0.81%), > 9: 4,537 (0.24%), > 10: 1,566 (0.08%)
# enhanced_Historical_100_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7890 max=22.5014 avg=5.8020 | > 5: 692,717 (86.44%), > 7: 61,009 (7.61%), > 8: 15,912 (1.99%), > 9: 4,919 (0.61%), > 10: 1,706 (0.21%)
# enhanced_Historical_100_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7277 max=22.5014 avg=5.6651 | > 5: 1,100,645 (82.41%), > 7: 73,859 (5.53%), > 8: 18,665 (1.40%), > 9: 5,589 (0.42%), > 10: 1,954 (0.15%)
# enhanced_Historical_100_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6796 max=22.5014 avg=5.5760 | > 5: 1,481,177 (79.21%), > 7: 82,604 (4.42%), > 8: 20,470 (1.09%), > 9: 6,016 (0.32%), > 10: 2,094 (0.11%)
# enhanced_Historical_200_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7759 max=19.3945 avg=5.6893 | > 5: 669,121 (83.50%), > 7: 45,228 (5.64%), > 8: 11,122 (1.39%), > 9: 3,363 (0.42%), > 10: 1,197 (0.15%)
# enhanced_Historical_200_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7148 max=19.3945 avg=5.5746 | > 5: 1,061,650 (79.49%), > 7: 56,062 (4.20%), > 8: 13,298 (1.00%), > 9: 3,997 (0.30%), > 10: 1,450 (0.11%)
# enhanced_Historical_200_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6834 max=19.3945 avg=5.4980 | > 5: 1,428,025 (76.37%), > 7: 63,814 (3.41%), > 8: 14,743 (0.79%), > 9: 4,419 (0.24%), > 10: 1,639 (0.09%)
# enhanced_Historical_25_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7369 max=24.2758 avg=5.7264 | > 5: 674,019 (84.11%), > 7: 52,597 (6.56%), > 8: 13,948 (1.74%), > 9: 4,405 (0.55%), > 10: 1,573 (0.20%)
# enhanced_Historical_25_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7047 max=24.2758 avg=5.6033 | > 5: 1,069,542 (80.08%), > 7: 64,378 (4.82%), > 8: 16,429 (1.23%), > 9: 5,037 (0.38%), > 10: 1,793 (0.13%)
# enhanced_Historical_25_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6514 max=24.2758 avg=5.5230 | > 5: 1,440,111 (77.02%), > 7: 72,582 (3.88%), > 8: 18,122 (0.97%), > 9: 5,429 (0.29%), > 10: 1,950 (0.10%)
# enhanced_Historical_50_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7741 max=21.1530 avg=5.7598 | > 5: 684,256 (85.39%), > 7: 55,885 (6.97%), > 8: 14,841 (1.85%), > 9: 4,677 (0.58%), > 10: 1,677 (0.21%)
# enhanced_Historical_50_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7443 max=21.1530 avg=5.6289 | > 5: 1,085,798 (81.30%), > 7: 68,066 (5.10%), > 8: 17,546 (1.31%), > 9: 5,301 (0.40%), > 10: 1,877 (0.14%)
# enhanced_Historical_50_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.7003 max=21.1530 avg=5.5440 | > 5: 1,459,883 (78.08%), > 7: 76,456 (4.09%), > 8: 19,327 (1.03%), > 9: 5,716 (0.31%), > 10: 2,019 (0.11%)
# enhanced_Horror_100_pos5_neg0_sample_15recommendation.csv    | rows=801,360 | min=1.7573 max=19.6913 avg=5.7201 | > 5: 676,786 (84.45%), > 7: 49,411 (6.17%), > 8: 12,522 (1.56%), > 9: 3,841 (0.48%), > 10: 1,381 (0.17%)
# enhanced_Horror_100_pos5_neg0_sample_25recommendation.csv    | rows=1,335,600 | min=1.7021 max=19.6913 avg=5.6016 | > 5: 1,075,631 (80.54%), > 7: 60,964 (4.56%), > 8: 15,011 (1.12%), > 9: 4,499 (0.34%), > 10: 1,613 (0.12%)
# enhanced_Horror_100_pos5_neg0_sample_35recommendation.csv    | rows=1,869,840 | min=1.6840 max=19.6913 avg=5.5232 | > 5: 1,447,975 (77.44%), > 7: 69,147 (3.70%), > 8: 16,656 (0.89%), > 9: 4,947 (0.26%), > 10: 1,781 (0.10%)
# enhanced_Horror_200_pos5_neg0_sample_15recommendation.csv    | rows=801,360 | min=1.7856 max=18.5706 avg=5.6987 | > 5: 673,674 (84.07%), > 7: 46,709 (5.83%), > 8: 12,244 (1.53%), > 9: 3,831 (0.48%), > 10: 1,369 (0.17%)
# enhanced_Horror_200_pos5_neg0_sample_25recommendation.csv    | rows=1,335,600 | min=1.7078 max=18.5706 avg=5.5852 | > 5: 1,070,940 (80.18%), > 7: 58,489 (4.38%), > 8: 14,732 (1.10%), > 9: 4,552 (0.34%), > 10: 1,579 (0.12%)
# enhanced_Horror_200_pos5_neg0_sample_35recommendation.csv    | rows=1,869,840 | min=1.6804 max=18.5706 avg=5.5094 | > 5: 1,441,544 (77.09%), > 7: 66,820 (3.57%), > 8: 16,428 (0.88%), > 9: 5,004 (0.27%), > 10: 1,719 (0.09%)
# enhanced_Horror_25_pos5_neg0_sample_15recommendation.csv     | rows=801,360 | min=1.7113 max=23.4621 avg=5.7185 | > 5: 674,688 (84.19%), > 7: 51,030 (6.37%), > 8: 13,152 (1.64%), > 9: 4,122 (0.51%), > 10: 1,579 (0.20%)
# enhanced_Horror_25_pos5_neg0_sample_25recommendation.csv     | rows=1,335,600 | min=1.6807 max=23.4621 avg=5.6000 | > 5: 1,074,144 (80.42%), > 7: 62,823 (4.70%), > 8: 15,400 (1.15%), > 9: 4,823 (0.36%), > 10: 1,853 (0.14%)
# enhanced_Horror_25_pos5_neg0_sample_35recommendation.csv     | rows=1,869,840 | min=1.6426 max=23.4621 avg=5.5213 | > 5: 1,447,332 (77.40%), > 7: 70,988 (3.80%), > 8: 16,913 (0.90%), > 9: 5,338 (0.29%), > 10: 2,025 (0.11%)
# enhanced_Horror_50_pos5_neg0_sample_15recommendation.csv     | rows=801,360 | min=1.8236 max=24.2506 avg=5.7229 | > 5: 676,239 (84.39%), > 7: 51,352 (6.41%), > 8: 13,342 (1.66%), > 9: 4,227 (0.53%), > 10: 1,529 (0.19%)
# enhanced_Horror_50_pos5_neg0_sample_25recommendation.csv     | rows=1,335,600 | min=1.7195 max=24.2506 avg=5.6019 | > 5: 1,075,010 (80.49%), > 7: 63,367 (4.74%), > 8: 15,710 (1.18%), > 9: 4,897 (0.37%), > 10: 1,810 (0.14%)
# enhanced_Horror_50_pos5_neg0_sample_35recommendation.csv     | rows=1,869,840 | min=1.6803 max=24.2506 avg=5.5226 | > 5: 1,447,963 (77.44%), > 7: 71,484 (3.82%), > 8: 17,406 (0.93%), > 9: 5,371 (0.29%), > 10: 2,033 (0.11%)
# enhanced_Mystery_100_pos5_neg0_sample_15recommendation.csv   | rows=801,360 | min=1.7657 max=20.6266 avg=5.7191 | > 5: 676,954 (84.48%), > 7: 49,253 (6.15%), > 8: 11,927 (1.49%), > 9: 3,556 (0.44%), > 10: 1,356 (0.17%)
# enhanced_Mystery_100_pos5_neg0_sample_25recommendation.csv   | rows=1,335,600 | min=1.7150 max=20.6266 avg=5.5981 | > 5: 1,075,190 (80.50%), > 7: 60,099 (4.50%), > 8: 14,043 (1.05%), > 9: 4,146 (0.31%), > 10: 1,618 (0.12%)
# enhanced_Mystery_100_pos5_neg0_sample_35recommendation.csv   | rows=1,869,840 | min=1.6920 max=20.6266 avg=5.5182 | > 5: 1,445,841 (77.32%), > 7: 67,264 (3.60%), > 8: 15,478 (0.83%), > 9: 4,598 (0.25%), > 10: 1,795 (0.10%)
# enhanced_Mystery_200_pos5_neg0_sample_15recommendation.csv   | rows=801,360 | min=1.7222 max=22.4928 avg=5.6230 | > 5: 652,244 (81.39%), > 7: 38,931 (4.86%), > 8: 9,749 (1.22%), > 9: 3,040 (0.38%), > 10: 1,116 (0.14%)
# enhanced_Mystery_200_pos5_neg0_sample_25recommendation.csv   | rows=1,335,600 | min=1.6638 max=22.4928 avg=5.5128 | > 5: 1,030,534 (77.16%), > 7: 47,883 (3.59%), > 8: 11,650 (0.87%), > 9: 3,557 (0.27%), > 10: 1,263 (0.09%)
# enhanced_Mystery_200_pos5_neg0_sample_35recommendation.csv   | rows=1,869,840 | min=1.6346 max=22.4928 avg=5.4396 | > 5: 1,381,072 (73.86%), > 7: 54,213 (2.90%), > 8: 12,997 (0.70%), > 9: 3,882 (0.21%), > 10: 1,344 (0.07%)
# enhanced_Mystery_25_pos5_neg0_sample_15recommendation.csv    | rows=801,360 | min=1.7360 max=24.7267 avg=5.7264 | > 5: 677,272 (84.52%), > 7: 51,320 (6.40%), > 8: 13,371 (1.67%), > 9: 4,413 (0.55%), > 10: 1,642 (0.20%)
# enhanced_Mystery_25_pos5_neg0_sample_25recommendation.csv    | rows=1,335,600 | min=1.6938 max=24.7267 avg=5.5978 | > 5: 1,073,159 (80.35%), > 7: 61,776 (4.63%), > 8: 15,672 (1.17%), > 9: 5,082 (0.38%), > 10: 1,859 (0.14%)
# enhanced_Mystery_25_pos5_neg0_sample_35recommendation.csv    | rows=1,869,840 | min=1.6616 max=24.7267 avg=5.5143 | > 5: 1,441,556 (77.10%), > 7: 68,961 (3.69%), > 8: 17,228 (0.92%), > 9: 5,563 (0.30%), > 10: 2,004 (0.11%)
# enhanced_Mystery_50_pos5_neg0_sample_15recommendation.csv    | rows=801,360 | min=1.7424 max=22.4388 avg=5.7063 | > 5: 670,807 (83.71%), > 7: 50,574 (6.31%), > 8: 13,261 (1.65%), > 9: 4,089 (0.51%), > 10: 1,506 (0.19%)
# enhanced_Mystery_50_pos5_neg0_sample_25recommendation.csv    | rows=1,335,600 | min=1.7227 max=22.4388 avg=5.5833 | > 5: 1,062,656 (79.56%), > 7: 61,569 (4.61%), > 8: 15,683 (1.17%), > 9: 4,751 (0.36%), > 10: 1,765 (0.13%)
# enhanced_Mystery_50_pos5_neg0_sample_35recommendation.csv    | rows=1,869,840 | min=1.6810 max=22.4388 avg=5.5029 | > 5: 1,427,153 (76.32%), > 7: 69,095 (3.70%), > 8: 17,279 (0.92%), > 9: 5,182 (0.28%), > 10: 1,916 (0.10%)
# enhanced_Nonfiction_100_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7596 max=20.4768 avg=5.7169 | > 5: 678,843 (84.71%), > 7: 47,481 (5.93%), > 8: 11,377 (1.42%), > 9: 3,421 (0.43%), > 10: 1,160 (0.14%)
# enhanced_Nonfiction_100_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7205 max=20.4768 avg=5.5999 | > 5: 1,079,513 (80.83%), > 7: 58,721 (4.40%), > 8: 13,817 (1.03%), > 9: 4,092 (0.31%), > 10: 1,371 (0.10%)
# enhanced_Nonfiction_100_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6826 max=20.4768 avg=5.5215 | > 5: 1,453,055 (77.71%), > 7: 66,348 (3.55%), > 8: 15,452 (0.83%), > 9: 4,525 (0.24%), > 10: 1,486 (0.08%)
# enhanced_Nonfiction_200_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7712 max=18.7065 avg=5.6653 | > 5: 664,022 (82.86%), > 7: 42,754 (5.34%), > 8: 10,797 (1.35%), > 9: 3,224 (0.40%), > 10: 1,118 (0.14%)
# enhanced_Nonfiction_200_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.6842 max=18.7065 avg=5.5531 | > 5: 1,053,699 (78.89%), > 7: 52,774 (3.95%), > 8: 12,819 (0.96%), > 9: 3,796 (0.28%), > 10: 1,284 (0.10%)
# enhanced_Nonfiction_200_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6464 max=18.7065 avg=5.4787 | > 5: 1,417,401 (75.80%), > 7: 59,760 (3.20%), > 8: 14,191 (0.76%), > 9: 4,179 (0.22%), > 10: 1,364 (0.07%)
# enhanced_Nonfiction_25_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7158 max=19.2084 avg=5.7395 | > 5: 679,545 (84.80%), > 7: 53,615 (6.69%), > 8: 14,041 (1.75%), > 9: 4,354 (0.54%), > 10: 1,475 (0.18%)
# enhanced_Nonfiction_25_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.6654 max=19.2084 avg=5.6132 | > 5: 1,078,243 (80.73%), > 7: 65,654 (4.92%), > 8: 16,529 (1.24%), > 9: 5,006 (0.37%), > 10: 1,669 (0.12%)
# enhanced_Nonfiction_25_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6355 max=19.2084 avg=5.5305 | > 5: 1,450,346 (77.57%), > 7: 73,866 (3.95%), > 8: 18,195 (0.97%), > 9: 5,386 (0.29%), > 10: 1,789 (0.10%)
# enhanced_Nonfiction_50_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.8056 max=22.3843 avg=5.7361 | > 5: 678,639 (84.69%), > 7: 53,786 (6.71%), > 8: 13,500 (1.68%), > 9: 4,159 (0.52%), > 10: 1,421 (0.18%)
# enhanced_Nonfiction_50_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7401 max=22.3843 avg=5.6125 | > 5: 1,077,246 (80.66%), > 7: 65,817 (4.93%), > 8: 15,982 (1.20%), > 9: 4,799 (0.36%), > 10: 1,651 (0.12%)
# enhanced_Nonfiction_50_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.7165 max=22.3843 avg=5.5314 | > 5: 1,449,624 (77.53%), > 7: 74,088 (3.96%), > 8: 17,719 (0.95%), > 9: 5,219 (0.28%), > 10: 1,792 (0.10%)
# enhanced_Romance_100_pos5_neg0_sample_15recommendation.csv   | rows=801,360 | min=1.8304 max=20.8314 avg=5.6865 | > 5: 673,258 (84.01%), > 7: 44,066 (5.50%), > 8: 11,158 (1.39%), > 9: 3,251 (0.41%), > 10: 1,238 (0.15%)
# enhanced_Romance_100_pos5_neg0_sample_25recommendation.csv   | rows=1,335,600 | min=1.7711 max=20.8314 avg=5.5704 | > 5: 1,067,620 (79.94%), > 7: 54,121 (4.05%), > 8: 13,274 (0.99%), > 9: 3,847 (0.29%), > 10: 1,477 (0.11%)
# enhanced_Romance_100_pos5_neg0_sample_35recommendation.csv   | rows=1,869,840 | min=1.7064 max=20.8314 avg=5.4938 | > 5: 1,434,088 (76.70%), > 7: 61,183 (3.27%), > 8: 14,616 (0.78%), > 9: 4,303 (0.23%), > 10: 1,618 (0.09%)
# enhanced_Romance_200_pos5_neg0_sample_15recommendation.csv   | rows=801,360 | min=1.7719 max=17.5116 avg=5.6216 | > 5: 656,589 (81.93%), > 7: 37,583 (4.69%), > 8: 9,236 (1.15%), > 9: 2,664 (0.33%), > 10: 961 (0.12%)
# enhanced_Romance_200_pos5_neg0_sample_25recommendation.csv   | rows=1,335,600 | min=1.7210 max=17.5116 avg=5.5133 | > 5: 1,037,725 (77.70%), > 7: 46,454 (3.48%), > 8: 11,004 (0.82%), > 9: 3,176 (0.24%), > 10: 1,151 (0.09%)
# enhanced_Romance_200_pos5_neg0_sample_35recommendation.csv   | rows=1,869,840 | min=1.6865 max=17.5116 avg=5.4406 | > 5: 1,391,592 (74.42%), > 7: 52,616 (2.81%), > 8: 12,206 (0.65%), > 9: 3,530 (0.19%), > 10: 1,268 (0.07%)
# enhanced_Romance_25_pos5_neg0_sample_15recommendation.csv    | rows=801,360 | min=1.7953 max=22.0460 avg=5.6955 | > 5: 674,833 (84.21%), > 7: 45,608 (5.69%), > 8: 11,686 (1.46%), > 9: 3,615 (0.45%), > 10: 1,237 (0.15%)
# enhanced_Romance_25_pos5_neg0_sample_25recommendation.csv    | rows=1,335,600 | min=1.7156 max=22.0460 avg=5.5763 | > 5: 1,069,310 (80.06%), > 7: 56,048 (4.20%), > 8: 13,855 (1.04%), > 9: 4,203 (0.31%), > 10: 1,418 (0.11%)
# enhanced_Romance_25_pos5_neg0_sample_35recommendation.csv    | rows=1,869,840 | min=1.6887 max=22.0460 avg=5.4985 | > 5: 1,437,195 (76.86%), > 7: 63,366 (3.39%), > 8: 15,407 (0.82%), > 9: 4,569 (0.24%), > 10: 1,556 (0.08%)
# enhanced_Romance_50_pos5_neg0_sample_15recommendation.csv    | rows=801,360 | min=1.8468 max=20.7227 avg=5.6670 | > 5: 671,781 (83.83%), > 7: 41,374 (5.16%), > 8: 10,657 (1.33%), > 9: 3,321 (0.41%), > 10: 1,137 (0.14%)
# enhanced_Romance_50_pos5_neg0_sample_25recommendation.csv    | rows=1,335,600 | min=1.7520 max=20.7227 avg=5.5575 | > 5: 1,064,763 (79.72%), > 7: 51,325 (3.84%), > 8: 12,795 (0.96%), > 9: 3,841 (0.29%), > 10: 1,352 (0.10%)
# enhanced_Romance_50_pos5_neg0_sample_35recommendation.csv    | rows=1,869,840 | min=1.7162 max=20.7227 avg=5.4845 | > 5: 1,431,272 (76.55%), > 7: 58,363 (3.12%), > 8: 14,234 (0.76%), > 9: 4,181 (0.22%), > 10: 1,497 (0.08%)
# enhanced_Science_Fiction_100_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7527 max=23.5463 avg=5.7358 | > 5: 683,805 (85.33%), > 7: 49,337 (6.16%), > 8: 12,511 (1.56%), > 9: 3,907 (0.49%), > 10: 1,460 (0.18%)
# enhanced_Science_Fiction_100_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7054 max=23.5463 avg=5.6142 | > 5: 1,085,706 (81.29%), > 7: 60,992 (4.57%), > 8: 15,055 (1.13%), > 9: 4,583 (0.34%), > 10: 1,728 (0.13%)
# enhanced_Science_Fiction_100_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6679 max=23.5463 avg=5.5338 | > 5: 1,460,622 (78.11%), > 7: 69,136 (3.70%), > 8: 16,736 (0.90%), > 9: 5,034 (0.27%), > 10: 1,924 (0.10%)
# enhanced_Science_Fiction_200_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.8102 max=18.6008 avg=5.6844 | > 5: 668,478 (83.42%), > 7: 45,059 (5.62%), > 8: 11,237 (1.40%), > 9: 3,358 (0.42%), > 10: 1,251 (0.16%)
# enhanced_Science_Fiction_200_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7533 max=18.6008 avg=5.5689 | > 5: 1,059,114 (79.30%), > 7: 56,117 (4.20%), > 8: 13,642 (1.02%), > 9: 3,973 (0.30%), > 10: 1,548 (0.12%)
# enhanced_Science_Fiction_200_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.7120 max=18.6008 avg=5.4919 | > 5: 1,422,403 (76.07%), > 7: 63,778 (3.41%), > 8: 15,237 (0.81%), > 9: 4,406 (0.24%), > 10: 1,755 (0.09%)
# enhanced_Science_Fiction_25_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7378 max=19.7070 avg=5.7206 | > 5: 677,066 (84.49%), > 7: 49,663 (6.20%), > 8: 12,666 (1.58%), > 9: 4,007 (0.50%), > 10: 1,443 (0.18%)
# enhanced_Science_Fiction_25_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.6966 max=19.7070 avg=5.5977 | > 5: 1,074,654 (80.46%), > 7: 61,082 (4.57%), > 8: 15,112 (1.13%), > 9: 4,623 (0.35%), > 10: 1,657 (0.12%)
# enhanced_Science_Fiction_25_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6682 max=19.7070 avg=5.5172 | > 5: 1,445,967 (77.33%), > 7: 68,960 (3.69%), > 8: 16,845 (0.90%), > 9: 5,032 (0.27%), > 10: 1,795 (0.10%)
# enhanced_Science_Fiction_50_pos5_neg0_sample_15recommendation.csv | rows=801,360 | min=1.7762 max=21.7861 avg=5.7050 | > 5: 670,631 (83.69%), > 7: 50,718 (6.33%), > 8: 12,953 (1.62%), > 9: 4,185 (0.52%), > 10: 1,560 (0.19%)
# enhanced_Science_Fiction_50_pos5_neg0_sample_25recommendation.csv | rows=1,335,600 | min=1.7255 max=21.7861 avg=5.5872 | > 5: 1,064,814 (79.73%), > 7: 62,494 (4.68%), > 8: 15,403 (1.15%), > 9: 4,930 (0.37%), > 10: 1,798 (0.13%)
# enhanced_Science_Fiction_50_pos5_neg0_sample_35recommendation.csv | rows=1,869,840 | min=1.6961 max=21.7861 avg=5.5092 | > 5: 1,432,434 (76.61%), > 7: 70,250 (3.76%), > 8: 17,074 (0.91%), > 9: 5,442 (0.29%), > 10: 1,954 (0.10%)
# enhanced_Thriller_100_pos5_neg0_sample_15recommendation.csv  | rows=801,360 | min=1.7455 max=24.1137 avg=5.7564 | > 5: 683,907 (85.34%), > 7: 53,881 (6.72%), > 8: 13,435 (1.68%), > 9: 4,283 (0.53%), > 10: 1,583 (0.20%)
# enhanced_Thriller_100_pos5_neg0_sample_25recommendation.csv  | rows=1,335,600 | min=1.6959 max=24.1137 avg=5.6305 | > 5: 1,087,147 (81.40%), > 7: 66,037 (4.94%), > 8: 15,965 (1.20%), > 9: 5,013 (0.38%), > 10: 1,764 (0.13%)
# enhanced_Thriller_100_pos5_neg0_sample_35recommendation.csv  | rows=1,869,840 | min=1.6508 max=24.1137 avg=5.5477 | > 5: 1,464,093 (78.30%), > 7: 74,404 (3.98%), > 8: 17,769 (0.95%), > 9: 5,496 (0.29%), > 10: 1,890 (0.10%)
# enhanced_Thriller_200_pos5_neg0_sample_15recommendation.csv  | rows=801,360 | min=1.7894 max=23.3950 avg=5.7097 | > 5: 674,146 (84.13%), > 7: 48,533 (6.06%), > 8: 12,904 (1.61%), > 9: 4,253 (0.53%), > 10: 1,521 (0.19%)
# enhanced_Thriller_200_pos5_neg0_sample_25recommendation.csv  | rows=1,335,600 | min=1.7220 max=23.3950 avg=5.5918 | > 5: 1,070,249 (80.13%), > 7: 60,143 (4.50%), > 8: 15,540 (1.16%), > 9: 5,036 (0.38%), > 10: 1,778 (0.13%)
# enhanced_Thriller_200_pos5_neg0_sample_35recommendation.csv  | rows=1,869,840 | min=1.6743 max=23.3950 avg=5.5135 | > 5: 1,440,082 (77.02%), > 7: 68,390 (3.66%), > 8: 17,324 (0.93%), > 9: 5,561 (0.30%), > 10: 1,947 (0.10%)
# enhanced_Thriller_25_pos5_neg0_sample_15recommendation.csv   | rows=801,360 | min=1.7748 max=17.8346 avg=5.7188 | > 5: 675,857 (84.34%), > 7: 50,250 (6.27%), > 8: 13,168 (1.64%), > 9: 4,197 (0.52%), > 10: 1,461 (0.18%)
# enhanced_Thriller_25_pos5_neg0_sample_25recommendation.csv   | rows=1,335,600 | min=1.7331 max=17.8346 avg=5.5982 | > 5: 1,073,312 (80.36%), > 7: 61,710 (4.62%), > 8: 15,647 (1.17%), > 9: 4,861 (0.36%), > 10: 1,670 (0.13%)
# enhanced_Thriller_25_pos5_neg0_sample_35recommendation.csv   | rows=1,869,840 | min=1.6726 max=17.8346 avg=5.5190 | > 5: 1,444,970 (77.28%), > 7: 69,805 (3.73%), > 8: 17,309 (0.93%), > 9: 5,249 (0.28%), > 10: 1,821 (0.10%)
# enhanced_Thriller_50_pos5_neg0_sample_15recommendation.csv   | rows=801,360 | min=1.7992 max=22.1780 avg=5.7201 | > 5: 675,720 (84.32%), > 7: 50,399 (6.29%), > 8: 12,761 (1.59%), > 9: 3,961 (0.49%), > 10: 1,341 (0.17%)
# enhanced_Thriller_50_pos5_neg0_sample_25recommendation.csv   | rows=1,335,600 | min=1.7219 max=22.1780 avg=5.6019 | > 5: 1,074,535 (80.45%), > 7: 62,140 (4.65%), > 8: 15,188 (1.14%), > 9: 4,640 (0.35%), > 10: 1,545 (0.12%)
# enhanced_Thriller_50_pos5_neg0_sample_35recommendation.csv   | rows=1,869,840 | min=1.6776 max=22.1780 avg=5.5234 | > 5: 1,446,526 (77.36%), > 7: 70,160 (3.75%), > 8: 16,879 (0.90%), > 9: 5,045 (0.27%), > 10: 1,655 (0.09%)
#
# ====================================================================================================
# [DIR] /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/0909/SVD
# ORIGINAL_15recommendation.csv                                | rows=801,360 | min=1.7773 max=25.7982 avg=5.7794 | > 5: 689,016 (85.98%), > 7: 58,331 (7.28%), > 8: 14,750 (1.84%), > 9: 4,644 (0.58%), > 10: 1,641 (0.20%)
# ORIGINAL_25recommendation.csv                                | rows=1,335,600 | min=1.7336 max=25.7982 avg=5.6452 | > 5: 1,092,827 (81.82%), > 7: 71,064 (5.32%), > 8: 17,485 (1.31%), > 9: 5,427 (0.41%), > 10: 1,906 (0.14%)
# ORIGINAL_35recommendation.csv                                | rows=1,869,840 | min=1.6932 max=25.7982 avg=5.5585 | > 5: 1,469,636 (78.60%), > 7: 79,564 (4.26%), > 8: 19,353 (1.04%), > 9: 5,887 (0.31%), > 10: 2,071 (0.11%)
# f_Adult_100_pos7_neg0_sample_15recommendation.csv            | rows=801,360 | min=1.7426 max=25.2889 avg=5.7874 | > 5: 687,660 (85.81%), > 7: 59,555 (7.43%), > 8: 15,237 (1.90%), > 9: 4,816 (0.60%), > 10: 1,849 (0.23%)
# f_Adult_100_pos7_neg0_sample_25recommendation.csv            | rows=1,335,600 | min=1.6843 max=25.2889 avg=5.6595 | > 5: 1,095,383 (82.01%), > 7: 73,167 (5.48%), > 8: 18,312 (1.37%), > 9: 5,681 (0.43%), > 10: 2,216 (0.17%)
# f_Adult_100_pos7_neg0_sample_35recommendation.csv            | rows=1,869,840 | min=1.6472 max=25.2889 avg=5.5745 | > 5: 1,476,241 (78.95%), > 7: 82,592 (4.42%), > 8: 20,340 (1.09%), > 9: 6,288 (0.34%), > 10: 2,445 (0.13%)
# f_Adult_200_pos7_neg0_sample_15recommendation.csv            | rows=801,360 | min=1.8207 max=15.5998 avg=5.7192 | > 5: 675,419 (84.28%), > 7: 49,813 (6.22%), > 8: 12,642 (1.58%), > 9: 3,857 (0.48%), > 10: 1,380 (0.17%)
# f_Adult_200_pos7_neg0_sample_25recommendation.csv            | rows=1,335,600 | min=1.7519 max=15.5998 avg=5.6010 | > 5: 1,073,599 (80.38%), > 7: 61,994 (4.64%), > 8: 15,076 (1.13%), > 9: 4,595 (0.34%), > 10: 1,610 (0.12%)
# f_Adult_200_pos7_neg0_sample_35recommendation.csv            | rows=1,869,840 | min=1.6967 max=15.5998 avg=5.5225 | > 5: 1,445,810 (77.32%), > 7: 70,645 (3.78%), > 8: 16,743 (0.90%), > 9: 5,059 (0.27%), > 10: 1,746 (0.09%)
# f_Adult_25_pos7_neg0_sample_15recommendation.csv             | rows=801,360 | min=1.7423 max=18.5463 avg=5.7278 | > 5: 680,505 (84.92%), > 7: 50,091 (6.25%), > 8: 12,674 (1.58%), > 9: 3,821 (0.48%), > 10: 1,433 (0.18%)
# f_Adult_25_pos7_neg0_sample_25recommendation.csv             | rows=1,335,600 | min=1.7026 max=18.5463 avg=5.6103 | > 5: 1,082,506 (81.05%), > 7: 62,427 (4.67%), > 8: 15,124 (1.13%), > 9: 4,505 (0.34%), > 10: 1,704 (0.13%)
# f_Adult_25_pos7_neg0_sample_35recommendation.csv             | rows=1,869,840 | min=1.6842 max=18.5463 avg=5.5322 | > 5: 1,458,807 (78.02%), > 7: 70,860 (3.79%), > 8: 16,811 (0.90%), > 9: 4,972 (0.27%), > 10: 1,882 (0.10%)
# f_Adult_50_pos7_neg0_sample_15recommendation.csv             | rows=801,360 | min=1.7916 max=25.5791 avg=5.7507 | > 5: 680,990 (84.98%), > 7: 55,458 (6.92%), > 8: 14,764 (1.84%), > 9: 4,756 (0.59%), > 10: 1,705 (0.21%)
# f_Adult_50_pos7_neg0_sample_25recommendation.csv             | rows=1,335,600 | min=1.7286 max=25.5791 avg=5.6276 | > 5: 1,083,527 (81.13%), > 7: 68,548 (5.13%), > 8: 17,601 (1.32%), > 9: 5,500 (0.41%), > 10: 1,958 (0.15%)
# f_Adult_50_pos7_neg0_sample_35recommendation.csv             | rows=1,869,840 | min=1.6922 max=25.5791 avg=5.5461 | > 5: 1,459,866 (78.07%), > 7: 77,564 (4.15%), > 8: 19,556 (1.05%), > 9: 5,935 (0.32%), > 10: 2,142 (0.11%)
# f_Adventure_100_pos7_neg0_sample_15recommendation.csv        | rows=801,360 | min=1.7325 max=23.4657 avg=5.7418 | > 5: 681,252 (85.01%), > 7: 51,476 (6.42%), > 8: 12,792 (1.60%), > 9: 3,727 (0.47%), > 10: 1,364 (0.17%)
# f_Adventure_100_pos7_neg0_sample_25recommendation.csv        | rows=1,335,600 | min=1.6823 max=23.4657 avg=5.6252 | > 5: 1,085,366 (81.26%), > 7: 64,215 (4.81%), > 8: 15,421 (1.15%), > 9: 4,438 (0.33%), > 10: 1,621 (0.12%)
# f_Adventure_100_pos7_neg0_sample_35recommendation.csv        | rows=1,869,840 | min=1.6599 max=23.4657 avg=5.5465 | > 5: 1,463,970 (78.29%), > 7: 73,102 (3.91%), > 8: 17,181 (0.92%), > 9: 4,907 (0.26%), > 10: 1,813 (0.10%)
# f_Adventure_200_pos7_neg0_sample_15recommendation.csv        | rows=801,360 | min=1.7920 max=21.5639 avg=5.7171 | > 5: 674,132 (84.12%), > 7: 49,504 (6.18%), > 8: 12,651 (1.58%), > 9: 3,937 (0.49%), > 10: 1,539 (0.19%)
# f_Adventure_200_pos7_neg0_sample_25recommendation.csv        | rows=1,335,600 | min=1.7423 max=21.5639 avg=5.6009 | > 5: 1,072,418 (80.29%), > 7: 61,092 (4.57%), > 8: 15,254 (1.14%), > 9: 4,704 (0.35%), > 10: 1,818 (0.14%)
# f_Adventure_200_pos7_neg0_sample_35recommendation.csv        | rows=1,869,840 | min=1.7060 max=21.5639 avg=5.5231 | > 5: 1,445,033 (77.28%), > 7: 69,109 (3.70%), > 8: 16,996 (0.91%), > 9: 5,236 (0.28%), > 10: 1,999 (0.11%)
# f_Adventure_25_pos7_neg0_sample_15recommendation.csv         | rows=801,360 | min=1.7301 max=20.4222 avg=5.7202 | > 5: 678,563 (84.68%), > 7: 49,701 (6.20%), > 8: 12,911 (1.61%), > 9: 4,068 (0.51%), > 10: 1,542 (0.19%)
# f_Adventure_25_pos7_neg0_sample_25recommendation.csv         | rows=1,335,600 | min=1.6899 max=20.4222 avg=5.6018 | > 5: 1,078,275 (80.73%), > 7: 61,396 (4.60%), > 8: 15,370 (1.15%), > 9: 4,812 (0.36%), > 10: 1,814 (0.14%)
# f_Adventure_25_pos7_neg0_sample_35recommendation.csv         | rows=1,869,840 | min=1.6554 max=20.4222 avg=5.5237 | > 5: 1,452,404 (77.68%), > 7: 69,554 (3.72%), > 8: 17,027 (0.91%), > 9: 5,341 (0.29%), > 10: 1,974 (0.11%)
# f_Adventure_50_pos7_neg0_sample_15recommendation.csv         | rows=801,360 | min=1.8134 max=23.1991 avg=5.7550 | > 5: 681,304 (85.02%), > 7: 56,692 (7.07%), > 8: 14,983 (1.87%), > 9: 4,714 (0.59%), > 10: 1,657 (0.21%)
# f_Adventure_50_pos7_neg0_sample_25recommendation.csv         | rows=1,335,600 | min=1.7242 max=23.1991 avg=5.6298 | > 5: 1,082,643 (81.06%), > 7: 69,629 (5.21%), > 8: 17,820 (1.33%), > 9: 5,499 (0.41%), > 10: 1,916 (0.14%)
# f_Adventure_50_pos7_neg0_sample_35recommendation.csv         | rows=1,869,840 | min=1.6704 max=23.1991 avg=5.5472 | > 5: 1,457,630 (77.95%), > 7: 78,659 (4.21%), > 8: 19,747 (1.06%), > 9: 5,982 (0.32%), > 10: 2,096 (0.11%)
# f_Children_s_100_pos7_neg0_sample_15recommendation.csv       | rows=801,360 | min=1.8284 max=21.8649 avg=5.7522 | > 5: 687,193 (85.75%), > 7: 51,520 (6.43%), > 8: 12,715 (1.59%), > 9: 3,867 (0.48%), > 10: 1,427 (0.18%)
# f_Children_s_100_pos7_neg0_sample_25recommendation.csv       | rows=1,335,600 | min=1.7244 max=21.8649 avg=5.6286 | > 5: 1,091,587 (81.73%), > 7: 63,540 (4.76%), > 8: 15,136 (1.13%), > 9: 4,684 (0.35%), > 10: 1,686 (0.13%)
# f_Children_s_100_pos7_neg0_sample_35recommendation.csv       | rows=1,869,840 | min=1.6835 max=21.8649 avg=5.5467 | > 5: 1,468,473 (78.53%), > 7: 72,026 (3.85%), > 8: 16,754 (0.90%), > 9: 5,229 (0.28%), > 10: 1,856 (0.10%)
# f_Children_s_200_pos7_neg0_sample_15recommendation.csv       | rows=801,360 | min=1.8533 max=16.9157 avg=5.7346 | > 5: 683,398 (85.28%), > 7: 50,798 (6.34%), > 8: 12,658 (1.58%), > 9: 3,711 (0.46%), > 10: 1,383 (0.17%)
# f_Children_s_200_pos7_neg0_sample_25recommendation.csv       | rows=1,335,600 | min=1.7774 max=16.9157 avg=5.6101 | > 5: 1,083,568 (81.13%), > 7: 62,300 (4.66%), > 8: 14,888 (1.11%), > 9: 4,400 (0.33%), > 10: 1,667 (0.12%)
# f_Children_s_200_pos7_neg0_sample_35recommendation.csv       | rows=1,869,840 | min=1.7200 max=16.9157 avg=5.5275 | > 5: 1,455,213 (77.83%), > 7: 69,967 (3.74%), > 8: 16,390 (0.88%), > 9: 4,900 (0.26%), > 10: 1,879 (0.10%)
# f_Children_s_25_pos7_neg0_sample_15recommendation.csv        | rows=801,360 | min=1.7235 max=20.6700 avg=5.7243 | > 5: 679,334 (84.77%), > 7: 49,577 (6.19%), > 8: 12,690 (1.58%), > 9: 3,870 (0.48%), > 10: 1,392 (0.17%)
# f_Children_s_25_pos7_neg0_sample_25recommendation.csv        | rows=1,335,600 | min=1.6967 max=20.6700 avg=5.6034 | > 5: 1,079,226 (80.80%), > 7: 60,926 (4.56%), > 8: 14,994 (1.12%), > 9: 4,496 (0.34%), > 10: 1,571 (0.12%)
# f_Children_s_25_pos7_neg0_sample_35recommendation.csv        | rows=1,869,840 | min=1.6653 max=20.6700 avg=5.5240 | > 5: 1,452,693 (77.69%), > 7: 68,680 (3.67%), > 8: 16,571 (0.89%), > 9: 4,926 (0.26%), > 10: 1,696 (0.09%)
# f_Children_s_50_pos7_neg0_sample_15recommendation.csv        | rows=801,360 | min=1.7608 max=23.5458 avg=5.7289 | > 5: 680,358 (84.90%), > 7: 51,055 (6.37%), > 8: 13,630 (1.70%), > 9: 4,277 (0.53%), > 10: 1,481 (0.18%)
# f_Children_s_50_pos7_neg0_sample_25recommendation.csv        | rows=1,335,600 | min=1.6960 max=23.5458 avg=5.6036 | > 5: 1,079,118 (80.80%), > 7: 62,227 (4.66%), > 8: 16,044 (1.20%), > 9: 4,853 (0.36%), > 10: 1,691 (0.13%)
# f_Children_s_50_pos7_neg0_sample_35recommendation.csv        | rows=1,869,840 | min=1.6645 max=23.5458 avg=5.5218 | > 5: 1,450,557 (77.58%), > 7: 69,769 (3.73%), > 8: 17,599 (0.94%), > 9: 5,196 (0.28%), > 10: 1,812 (0.10%)
# f_Classics_100_pos7_neg0_sample_15recommendation.csv         | rows=801,360 | min=1.8019 max=22.4981 avg=5.7376 | > 5: 680,890 (84.97%), > 7: 51,453 (6.42%), > 8: 12,576 (1.57%), > 9: 3,801 (0.47%), > 10: 1,329 (0.17%)
# f_Classics_100_pos7_neg0_sample_25recommendation.csv         | rows=1,335,600 | min=1.7192 max=22.4981 avg=5.6185 | > 5: 1,083,423 (81.12%), > 7: 63,516 (4.76%), > 8: 15,033 (1.13%), > 9: 4,490 (0.34%), > 10: 1,560 (0.12%)
# f_Classics_100_pos7_neg0_sample_35recommendation.csv         | rows=1,869,840 | min=1.6807 max=22.4981 avg=5.5387 | > 5: 1,459,399 (78.05%), > 7: 71,593 (3.83%), > 8: 16,804 (0.90%), > 9: 4,921 (0.26%), > 10: 1,699 (0.09%)
# f_Classics_200_pos7_neg0_sample_15recommendation.csv         | rows=801,360 | min=1.7362 max=16.6049 avg=5.7052 | > 5: 672,445 (83.91%), > 7: 48,622 (6.07%), > 8: 12,424 (1.55%), > 9: 3,953 (0.49%), > 10: 1,354 (0.17%)
# f_Classics_200_pos7_neg0_sample_25recommendation.csv         | rows=1,335,600 | min=1.6857 max=16.6049 avg=5.5911 | > 5: 1,070,060 (80.12%), > 7: 60,613 (4.54%), > 8: 15,082 (1.13%), > 9: 4,662 (0.35%), > 10: 1,558 (0.12%)
# f_Classics_200_pos7_neg0_sample_35recommendation.csv         | rows=1,869,840 | min=1.6485 max=16.6049 avg=5.5142 | > 5: 1,440,773 (77.05%), > 7: 68,658 (3.67%), > 8: 16,853 (0.90%), > 9: 5,091 (0.27%), > 10: 1,721 (0.09%)
# f_Classics_25_pos7_neg0_sample_15recommendation.csv          | rows=801,360 | min=1.7767 max=19.0021 avg=5.7141 | > 5: 675,868 (84.34%), > 7: 48,993 (6.11%), > 8: 12,606 (1.57%), > 9: 4,121 (0.51%), > 10: 1,587 (0.20%)
# f_Classics_25_pos7_neg0_sample_25recommendation.csv          | rows=1,335,600 | min=1.7261 max=19.0021 avg=5.5961 | > 5: 1,074,464 (80.45%), > 7: 60,547 (4.53%), > 8: 15,205 (1.14%), > 9: 4,851 (0.36%), > 10: 1,847 (0.14%)
# f_Classics_25_pos7_neg0_sample_35recommendation.csv          | rows=1,869,840 | min=1.6764 max=19.0021 avg=5.5181 | > 5: 1,446,794 (77.38%), > 7: 68,614 (3.67%), > 8: 16,926 (0.91%), > 9: 5,356 (0.29%), > 10: 2,017 (0.11%)
#
# ####################################################################################################
# # SUMMARY BY DIRECTORY
# /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/0902/SVD
#   files=159, rows=212,360,400 | > 5: 169,236,550 (79.69%) | > 7: 9,548,215 (4.50%) | > 8: 2,359,896 (1.11%) | > 9: 719,156 (0.34%) | > 10: 257,388 (0.12%)
#
# /home/moshtasa/Research/phd-svd-recsys/SVD/Book/result/rec/top_re/0909/SVD
#   files=48, rows=64,108,800 | > 5: 51,499,616 (80.33%) | > 7: 3,020,796 (4.71%) | > 8: 748,199 (1.17%) | > 9: 228,763 (0.36%) | > 10: 83,054 (0.13%)
